# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 시스템에 설치된 폰트 목록 출력
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    print(fm.FontProperties(fname=font).get_name(), font)
# Out:
# Corbel C:\Windows\Fonts\corbelb.ttf
# Broadway C:\Windows\Fonts\BROADW.TTF
# Leelawadee C:\Windows\Fonts\LEELAWDB.TTF
# Nirmala UI C:\Windows\Fonts\Nirmala.ttf
# Niagara Engraved C:\Windows\Fonts\NIAGENG.TTF
# Corbel C:\Windows\Fonts\corbell.ttf
# New Gulim C:\Windows\Fonts\NGULIM.TTF
# Han Santteut Dotum C:\Windows\Fonts\HanSantteutDotum-Regular.ttf
# Bradley Hand ITC C:\Windows\Fonts\BRADHITC.TTF
# Tw Cen MT C:\Windows\Fonts\TCB_____.TTF
# Arial C:\Windows\Fonts\ARIALN.TTF
# Goudy Old Style C:\Windows\Fonts\GOUDOSB.TTF
# Calisto MT C:\Windows\Fonts\CALIST.TTF
# Sitka C:\Windows\Fonts\SitkaVF-Italic.ttf
# Snap ITC C:\Windows\Fonts\SNAP____.TTF
# Impact C:\Windows\Fonts\impact.ttf
# Nirmala UI C:\Windows\Fonts\NirmalaS.ttf
# Californian FB C:\Windows\Fonts\CALIFR.TTF
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Microsoft Sans Serif C:\Windows\Fonts\micross.ttf
# Elephant C:\Windows\Fonts\ELEPHNTI.TTF
# Malgun Gothic C:\Windows\Fonts\malgun.ttf
# Webdings C:\Windows\Fonts\webdings.ttf
# Forte C:\Windows\Fonts\FORTE.TTF
# Bahnschrift C:\Windows\Fonts\bahnschrift.ttf
# Verdana C:\Windows\Fonts\verdanab.ttf
# Franklin Gothic Demi C:\Windows\Fonts\FRADM.TTF
# Bodoni MT C:\Windows\Fonts\BOD_R.TTF
# Constantia C:\Windows\Fonts\constanb.ttf
# Bookman Old Style C:\Windows\Fonts\BOOKOSI.TTF
# Gill Sans MT C:\Windows\Fonts\GILB____.TTF
# Rockwell C:\Windows\Fonts\ROCKI.TTF
# Gigi C:\Windows\Fonts\GIGI.TTF
# Book Antiqua C:\Windows\Fonts\BKANT.TTF
# HYPost-Light C:\Windows\Fonts\H2PORL.TTF
# Chiller C:\Windows\Fonts\CHILLER.TTF
# Eras Light ITC C:\Windows\Fonts\ERASLGHT.TTF
# Cooper Black C:\Windows\Fonts\COOPBL.TTF
# SimSun C:\Windows\Fonts\simsun.ttc
# Times New Roman C:\Windows\Fonts\timesi.ttf
# Lucida Bright C:\Windows\Fonts\LBRITEI.TTF
# Candara C:\Windows\Fonts\Candarai.ttf
# Franklin Gothic Medium C:\Windows\Fonts\framd.ttf
# Segoe UI Emoji C:\Windows\Fonts\seguiemj.ttf
# Franklin Gothic Medium Cond C:\Windows\Fonts\FRAMDCN.TTF
# Gulim C:\Windows\Fonts\gulim.ttc
# HYSinMyeongJo-Medium C:\Windows\Fonts\H2MJSM.TTF
# LG PC C:\Windows\Fonts\LG PC.ttf
# Harlow Solid Italic C:\Windows\Fonts\HARLOWSI.TTF
# Berlin Sans FB C:\Windows\Fonts\BRLNSR.TTF
# HYGothic-Extra C:\Windows\Fonts\H2GTRE.TTF
# Imprint MT Shadow C:\Windows\Fonts\IMPRISHA.TTF
# Segoe Script C:\Windows\Fonts\segoescb.ttf
# Gadugi C:\Windows\Fonts\gadugi.ttf
# Microsoft Uighur C:\Windows\Fonts\MSUIGHUR.TTF
# Leelawadee C:\Windows\Fonts\LEELAWAD.TTF
# Trebuchet MS C:\Windows\Fonts\trebucit.ttf
# Rockwell C:\Windows\Fonts\ROCKB.TTF
# HCR Dotum C:\Windows\Fonts\HANDotumB.ttf
# Poor Richard C:\Windows\Fonts\POORICH.TTF
# Viner Hand ITC C:\Windows\Fonts\VINERITC.TTF
# Maiandra GD C:\Windows\Fonts\MAIAN.TTF
# Cambria C:\Windows\Fonts\cambriab.ttf
# Calisto MT C:\Windows\Fonts\CALISTI.TTF
# MS Reference Sans Serif C:\Windows\Fonts\REFSAN.TTF
# Calisto MT C:\Windows\Fonts\CALISTB.TTF
# Georgia C:\Windows\Fonts\georgiab.ttf
# Tw Cen MT Condensed Extra Bold C:\Windows\Fonts\TCCEB.TTF
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Algerian C:\Windows\Fonts\ALGER.TTF
# HYGungSo-Bold C:\Windows\Fonts\H2GSRB.TTF
# Felix Titling C:\Windows\Fonts\FELIXTI.TTF
# Constantia C:\Windows\Fonts\constan.ttf
# Palatino Linotype C:\Windows\Fonts\pala.ttf
# Matura MT Script Capitals C:\Windows\Fonts\MATURASC.TTF
# Haan Wing2 C:\Windows\Fonts\HANWing2.ttf
# MS Reference Specialty C:\Windows\Fonts\REFSPCL.TTF
# Perpetua C:\Windows\Fonts\PERI____.TTF
# MingLiU-ExtB C:\Windows\Fonts\mingliub.ttc
# Tw Cen MT C:\Windows\Fonts\TCM_____.TTF
# Javanese Text C:\Windows\Fonts\javatext.ttf
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-Light.ttf
# Informal Roman C:\Windows\Fonts\INFROMAN.TTF
# Verdana C:\Windows\Fonts\verdanaz.ttf
# Myanmar Text C:\Windows\Fonts\mmrtext.ttf
# Tahoma C:\Windows\Fonts\tahomabd.ttf
# Segoe UI C:\Windows\Fonts\seguibl.ttf
# Consolas C:\Windows\Fonts\consolaz.ttf
# Segoe UI C:\Windows\Fonts\segoeui.ttf
# Garamond C:\Windows\Fonts\GARA.TTF
# Trebuchet MS C:\Windows\Fonts\trebucbi.ttf
# Colonna MT C:\Windows\Fonts\COLONNA.TTF
# Vladimir Script C:\Windows\Fonts\VLADIMIR.TTF
# Lucida Fax C:\Windows\Fonts\LFAXI.TTF
# Microsoft New Tai Lue C:\Windows\Fonts\ntailub.ttf
# Brush Script MT C:\Windows\Fonts\BRUSHSCI.TTF
# Consolas C:\Windows\Fonts\consolab.ttf
# Ink Free C:\Windows\Fonts\Inkfree.ttf
# Segoe Fluent Icons C:\Windows\Fonts\SegoeIcons.ttf
# Candara C:\Windows\Fonts\Candara.ttf
# HYMyeongJo-Extra C:\Windows\Fonts\H2MJRE.TTF
# Lucida Fax C:\Windows\Fonts\LFAX.TTF
# Arial Rounded MT Bold C:\Windows\Fonts\ARLRDBD.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# High Tower Text C:\Windows\Fonts\HTOWERTI.TTF
# Yu Gothic C:\Windows\Fonts\YuGothB.ttc
# Microsoft Yi Baiti C:\Windows\Fonts\msyi.ttf
# Footlight MT Light C:\Windows\Fonts\FTLTLT.TTF
# Ami R C:\Windows\Fonts\HMKMAMI.TTF
# Times New Roman C:\Windows\Fonts\times.ttf
# Segoe UI C:\Windows\Fonts\segoeuisl.ttf
# OCR A Extended C:\Windows\Fonts\OCRAEXT.TTF
# Niagara Solid C:\Windows\Fonts\NIAGSOL.TTF
# Corbel C:\Windows\Fonts\corbeli.ttf
# Calibri C:\Windows\Fonts\calibrili.ttf
# Century Schoolbook C:\Windows\Fonts\CENSCBK.TTF
# Sans Serif Collection C:\Windows\Fonts\SansSerifCollection.ttf
# Times New Roman C:\Windows\Fonts\timesbi.ttf
# Calibri C:\Windows\Fonts\calibriz.ttf
# Century Schoolbook C:\Windows\Fonts\SCHLBKBI.TTF
# Perpetua C:\Windows\Fonts\PER_____.TTF
# Lucida Handwriting C:\Windows\Fonts\LHANDW.TTF
# HYPMokGak-Bold C:\Windows\Fonts\H2MKPB.TTF
# Agency FB C:\Windows\Fonts\AGENCYB.TTF
# Century Gothic C:\Windows\Fonts\GOTHICBI.TTF
# Elephant C:\Windows\Fonts\ELEPHNT.TTF
# Book Antiqua C:\Windows\Fonts\ANTQUAB.TTF
# Corbel C:\Windows\Fonts\corbel.ttf
# Pyunji R C:\Windows\Fonts\HMFMPYUN.TTF
# Yu Gothic C:\Windows\Fonts\YuGothR.ttc
# Courier New C:\Windows\Fonts\courbi.ttf
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPEBO.TTF
# Courier New C:\Windows\Fonts\couri.ttf
# Haettenschweiler C:\Windows\Fonts\HATTEN.TTF
# Palace Script MT C:\Windows\Fonts\PALSCRI.TTF
# Gabriola C:\Windows\Fonts\Gabriola.ttf
# Malgun Gothic C:\Windows\Fonts\malgunsl.ttf
# HYHeadLine-Medium C:\Windows\Fonts\H2HDRM.TTF
# Ebrima C:\Windows\Fonts\ebrimabd.ttf
# Hancom Gothic C:\Windows\Fonts\Hancom Gothic Regular.ttf
# Times New Roman C:\Windows\Fonts\timesbd.ttf
# Bookshelf Symbol 7 C:\Windows\Fonts\BSSYM7.TTF
# Segoe Script C:\Windows\Fonts\segoesc.ttf
# Centaur C:\Windows\Fonts\CENTAUR.TTF
# Gill Sans MT C:\Windows\Fonts\GIL_____.TTF
# Rockwell Condensed C:\Windows\Fonts\ROCCB___.TTF
# Century Schoolbook C:\Windows\Fonts\SCHLBKB.TTF
# Goudy Old Style C:\Windows\Fonts\GOUDOSI.TTF
# Tw Cen MT C:\Windows\Fonts\TCMI____.TTF
# Franklin Gothic Heavy C:\Windows\Fonts\FRAHVIT.TTF
# Segoe UI C:\Windows\Fonts\segoeuii.ttf
# Arial C:\Windows\Fonts\ARIALNB.TTF
# Wingdings 2 C:\Windows\Fonts\WINGDNG2.TTF
# Gill Sans MT Condensed C:\Windows\Fonts\GILC____.TTF
# Gill Sans MT C:\Windows\Fonts\GILI____.TTF
# Garamond C:\Windows\Fonts\GARAIT.TTF
# Script MT Bold C:\Windows\Fonts\SCRIPTBL.TTF
# Calibri C:\Windows\Fonts\calibri.ttf
# Segoe Print C:\Windows\Fonts\segoepr.ttf
# Bodoni MT C:\Windows\Fonts\BOD_BI.TTF
# Century C:\Windows\Fonts\CENTURY.TTF
# Franklin Gothic Demi Cond C:\Windows\Fonts\FRADMCN.TTF
# Cascadia Code C:\Windows\Fonts\CascadiaCode.ttf
# Lucida Fax C:\Windows\Fonts\LFAXDI.TTF
# Californian FB C:\Windows\Fonts\CALIFI.TTF
# Constantia C:\Windows\Fonts\constani.ttf
# Calisto MT C:\Windows\Fonts\CALISTBI.TTF
# Engravers MT C:\Windows\Fonts\ENGR.TTF
# Leelawadee UI C:\Windows\Fonts\LeelaUIb.ttf
# Georgia C:\Windows\Fonts\georgia.ttf
# Vivaldi C:\Windows\Fonts\VIVALDII.TTF
# Franklin Gothic Demi C:\Windows\Fonts\FRADMIT.TTF
# Microsoft JhengHei C:\Windows\Fonts\msjh.ttc
# Segoe UI C:\Windows\Fonts\segoeuiz.ttf
# Symbol C:\Windows\Fonts\symbol.ttf
# Century Schoolbook C:\Windows\Fonts\SCHLBKI.TTF
# HCR Batang C:\Windows\Fonts\HANBatangB.ttf
# Verdana C:\Windows\Fonts\verdana.ttf
# Cambria C:\Windows\Fonts\cambriaz.ttf
# Stencil C:\Windows\Fonts\STENCIL.TTF
# Pristina C:\Windows\Fonts\PRISTINA.TTF
# Bodoni MT C:\Windows\Fonts\BOD_CB.TTF
# Bodoni MT C:\Windows\Fonts\BOD_CI.TTF
# Trebuchet MS C:\Windows\Fonts\trebuc.ttf
# Baskerville Old Face C:\Windows\Fonts\BASKVILL.TTF
# Nirmala UI C:\Windows\Fonts\NirmalaB.ttf
# Microsoft PhagsPa C:\Windows\Fonts\phagspab.ttf
# Arial C:\Windows\Fonts\ariblk.ttf
# Lucida Bright C:\Windows\Fonts\LBRITED.TTF
# Microsoft Himalaya C:\Windows\Fonts\himalaya.ttf
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-Regular.ttf
# Batang C:\Windows\Fonts\batang.ttc
# Rockwell Extra Bold C:\Windows\Fonts\ROCKEB.TTF
# Verdana C:\Windows\Fonts\verdanai.ttf
# Segoe UI Symbol C:\Windows\Fonts\seguisym.ttf
# Rage Italic C:\Windows\Fonts\RAGE.TTF
# Bodoni MT C:\Windows\Fonts\BOD_CBI.TTF
# HCR Batang ExtB C:\Windows\Fonts\HANBatangExtB.ttf
# Ebrima C:\Windows\Fonts\ebrima.ttf
# Tempus Sans ITC C:\Windows\Fonts\TEMPSITC.TTF
# Showcard Gothic C:\Windows\Fonts\SHOWG.TTF
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-SemiBold.ttf
# Lucida Sans C:\Windows\Fonts\LSANSD.TTF
# Microsoft Uighur C:\Windows\Fonts\MSUIGHUB.TTF
# Bodoni MT C:\Windows\Fonts\BOD_I.TTF
# Calibri C:\Windows\Fonts\calibrib.ttf
# Perpetua Titling MT C:\Windows\Fonts\PERTILI.TTF
# Berlin Sans FB Demi C:\Windows\Fonts\BRLNSDB.TTF
# Kunstler Script C:\Windows\Fonts\KUNSTLER.TTF
# Papyrus C:\Windows\Fonts\PAPYRUS.TTF
# Arial C:\Windows\Fonts\arial.ttf
# High Tower Text C:\Windows\Fonts\HTOWERT.TTF
# Onyx C:\Windows\Fonts\ONYX.TTF
# MoeumT R C:\Windows\Fonts\HMFMMUEX.TTC
# Segoe MDL2 Assets C:\Windows\Fonts\segmdl2.ttf
# Wingdings 3 C:\Windows\Fonts\WINGDNG3.TTF
# Trebuchet MS C:\Windows\Fonts\trebucbd.ttf
# Arial C:\Windows\Fonts\ARIALNI.TTF
# French Script MT C:\Windows\Fonts\FRSCRIPT.TTF
# Comic Sans MS C:\Windows\Fonts\comicz.ttf
# Berlin Sans FB C:\Windows\Fonts\BRLNSB.TTF
# Juice ITC C:\Windows\Fonts\JUICE___.TTF
# HCR Dotum Ext C:\Windows\Fonts\HANDotumExt.ttf
# Georgia C:\Windows\Fonts\georgiaz.ttf
# Gill Sans MT C:\Windows\Fonts\GILBI___.TTF
# Britannic Bold C:\Windows\Fonts\BRITANIC.TTF
# Segoe UI Variable C:\Windows\Fonts\SegUIVar.ttf
# Mongolian Baiti C:\Windows\Fonts\monbaiti.ttf
# Californian FB C:\Windows\Fonts\CALIFB.TTF
# Jokerman C:\Windows\Fonts\JOKERMAN.TTF
# Goudy Stout C:\Windows\Fonts\GOUDYSTO.TTF
# Book Antiqua C:\Windows\Fonts\ANTQUABI.TTF
# Hancom Hoonminjeongeum_H C:\Windows\Fonts\HancomHoonminjeongeumH.ttf
# MS Gothic C:\Windows\Fonts\msgothic.ttc
# Goudy Old Style C:\Windows\Fonts\GOUDOS.TTF
# Palatino Linotype C:\Windows\Fonts\palab.ttf
# Palatino Linotype C:\Windows\Fonts\palai.ttf
# Edwardian Script ITC C:\Windows\Fonts\ITCEDSCR.TTF
# Comic Sans MS C:\Windows\Fonts\comic.ttf
# Gloucester MT Extra Condensed C:\Windows\Fonts\GLECB.TTF
# Candara C:\Windows\Fonts\Candaral.ttf
# Bodoni MT C:\Windows\Fonts\BOD_B.TTF
# Candara C:\Windows\Fonts\Candarali.ttf
# Myanmar Text C:\Windows\Fonts\mmrtextb.ttf
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPEO.TTF
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-Bold.ttf
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPE.TTF
# Franklin Gothic Heavy C:\Windows\Fonts\FRAHV.TTF
# Headline R C:\Windows\Fonts\HMKMRHD.TTF
# Modern No. 20 C:\Windows\Fonts\MOD20.TTF
# Constantia C:\Windows\Fonts\constanz.ttf
# Blackadder ITC C:\Windows\Fonts\ITCBLKAD.TTF
# Perpetua C:\Windows\Fonts\PERBI___.TTF
# Palatino Linotype C:\Windows\Fonts\palabi.ttf
# Microsoft JhengHei C:\Windows\Fonts\msjhl.ttc
# Bell MT C:\Windows\Fonts\BELLB.TTF
# Bodoni MT C:\Windows\Fonts\BOD_PSTC.TTF
# Lucida Sans C:\Windows\Fonts\LSANSDI.TTF
# Leelawadee UI C:\Windows\Fonts\LeelawUI.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Leelawadee UI C:\Windows\Fonts\LeelUIsl.ttf
# Calibri C:\Windows\Fonts\calibrii.ttf
# MS Outlook C:\Windows\Fonts\OUTLOOK.TTF
# Wingdings C:\Windows\Fonts\wingding.ttf
# Gill Sans Ultra Bold C:\Windows\Fonts\GILSANUB.TTF
# Bookman Old Style C:\Windows\Fonts\BOOKOS.TTF
# Corbel C:\Windows\Fonts\corbelz.ttf
# Dubai C:\Windows\Fonts\DUBAI-BOLD.TTF
# Rockwell C:\Windows\Fonts\ROCK.TTF
# Bell MT C:\Windows\Fonts\BELLI.TTF
# HYShortSamul-Medium C:\Windows\Fonts\H2SA1M.TTF
# Calibri C:\Windows\Fonts\calibril.ttf
# NewJumja C:\Windows\Fonts\JUMJA.TTF
# Castellar C:\Windows\Fonts\CASTELAR.TTF
# Tw Cen MT Condensed C:\Windows\Fonts\TCCB____.TTF
# HYGothic-Medium C:\Windows\Fonts\H2GTRM.TTF
# Bodoni MT C:\Windows\Fonts\BOD_BLAR.TTF
# Lucida Bright C:\Windows\Fonts\LBRITE.TTF
# Mistral C:\Windows\Fonts\MISTRAL.TTF
# Gill Sans MT Ext Condensed Bold C:\Windows\Fonts\GLSNECB.TTF
# Ravie C:\Windows\Fonts\RAVIE.TTF
# Han Santteut Dotum C:\Windows\Fonts\HanSantteutDotum-Bold.ttf
# Magneto C:\Windows\Fonts\MAGNETOB.TTF
# Arial C:\Windows\Fonts\ARIALNBI.TTF
# Bookman Old Style C:\Windows\Fonts\BOOKOSBI.TTF
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPEB.TTF
# Arial C:\Windows\Fonts\ariali.ttf
# Lucida Sans C:\Windows\Fonts\LSANS.TTF
# HCR Batang C:\Windows\Fonts\HANBatang.ttf
# Lucida Fax C:\Windows\Fonts\LFAXD.TTF
# Lucida Sans C:\Windows\Fonts\LSANSI.TTF
# Bauhaus 93 C:\Windows\Fonts\BAUHS93.TTF
# Microsoft YaHei C:\Windows\Fonts\msyh.ttc
# Wide Latin C:\Windows\Fonts\LATINWD.TTF
# MT Extra C:\Windows\Fonts\MTEXTRA.TTF
# Curlz MT C:\Windows\Fonts\CURLZ___.TTF
# Cascadia Mono C:\Windows\Fonts\CascadiaMono.ttf
# SimSun-ExtB C:\Windows\Fonts\simsunb.ttf
# Yet R C:\Windows\Fonts\HMFMOLD.TTF
# Bernard MT Condensed C:\Windows\Fonts\BERNHC.TTF
# Lucida Console C:\Windows\Fonts\lucon.ttf
# Microsoft Tai Le C:\Windows\Fonts\taile.ttf
# Franklin Gothic Book C:\Windows\Fonts\FRABKIT.TTF
# Tw Cen MT C:\Windows\Fonts\TCBI____.TTF
# Arial C:\Windows\Fonts\arialbd.ttf
# Microsoft YaHei C:\Windows\Fonts\msyhl.ttc
# Candara C:\Windows\Fonts\Candarab.ttf
# Segoe UI Historic C:\Windows\Fonts\seguihis.ttf
# Candara C:\Windows\Fonts\Candaraz.ttf
# HoloLens MDL2 Assets C:\Windows\Fonts\holomdl2.ttf
# Kristen ITC C:\Windows\Fonts\ITCKRIST.TTF
# Segoe Print C:\Windows\Fonts\segoeprb.ttf
# Cambria C:\Windows\Fonts\cambria.ttc
# HyhwpEQ C:\Windows\Fonts\HYHWPEQ.TTF
# Segoe UI C:\Windows\Fonts\segoeuib.ttf
# Microsoft Tai Le C:\Windows\Fonts\taileb.ttf
# Book Antiqua C:\Windows\Fonts\ANTQUAI.TTF
# Freestyle Script C:\Windows\Fonts\FREESCPT.TTF
# Lucida Bright C:\Windows\Fonts\LBRITEDI.TTF
# Comic Sans MS C:\Windows\Fonts\comicbd.ttf
# Franklin Gothic Book C:\Windows\Fonts\FRABK.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Segoe UI C:\Windows\Fonts\segoeuil.ttf
# Tw Cen MT Condensed C:\Windows\Fonts\TCCM____.TTF
# Eras Bold ITC C:\Windows\Fonts\ERASBD.TTF
# Segoe UI C:\Windows\Fonts\seguisbi.ttf
# Perpetua Titling MT C:\Windows\Fonts\PERTIBD.TTF
# Microsoft JhengHei C:\Windows\Fonts\msjhbd.ttc
# Rockwell Condensed C:\Windows\Fonts\ROCC____.TTF
# Hancom Gothic C:\Windows\Fonts\Hancom Gothic Bold.ttf
# HancomEQN C:\Windows\Fonts\HancomEQN.ttf
# Parchment C:\Windows\Fonts\PARCHM.TTF
# Segoe UI C:\Windows\Fonts\seguisli.ttf
# Eras Medium ITC C:\Windows\Fonts\ERASMD.TTF
# Segoe UI C:\Windows\Fonts\seguili.ttf
# Segoe UI C:\Windows\Fonts\seguisb.ttf
# Cambria C:\Windows\Fonts\cambriai.ttf
# Bodoni MT C:\Windows\Fonts\BOD_BLAI.TTF
# Bell MT C:\Windows\Fonts\BELL.TTF
# Georgia C:\Windows\Fonts\georgiai.ttf
# Monotype Corsiva C:\Windows\Fonts\MTCORSVA.TTF
# Gill Sans Ultra Bold Condensed C:\Windows\Fonts\GILLUBCD.TTF
# Hancom MalangMalang C:\Windows\Fonts\MalangmalangB.ttf
# Hancom MalangMalang C:\Windows\Fonts\MalangmalangR.ttf
# Consolas C:\Windows\Fonts\consola.ttf
# Sitka C:\Windows\Fonts\SitkaVF.ttf
# Dubai C:\Windows\Fonts\DUBAI-REGULAR.TTF
# Copperplate Gothic Bold C:\Windows\Fonts\COPRGTB.TTF
# Gadugi C:\Windows\Fonts\gadugib.ttf
# Rockwell C:\Windows\Fonts\ROCKBI.TTF
# Tahoma C:\Windows\Fonts\tahoma.ttf
# Microsoft PhagsPa C:\Windows\Fonts\phagspa.ttf
# Garamond C:\Windows\Fonts\GARABD.TTF
# Dubai C:\Windows\Fonts\DUBAI-MEDIUM.TTF
# Sylfaen C:\Windows\Fonts\sylfaen.ttf
# Franklin Gothic Medium C:\Windows\Fonts\framdit.ttf
# HCR Batang ExtB C:\Windows\Fonts\HANBatangExtBB.ttf
# Perpetua C:\Windows\Fonts\PERB____.TTF
# Courier New C:\Windows\Fonts\cour.ttf
# Microsoft New Tai Lue C:\Windows\Fonts\ntailu.ttf
# Old English Text MT C:\Windows\Fonts\OLDENGL.TTF
# Microsoft YaHei C:\Windows\Fonts\msyhbd.ttc
# Consolas C:\Windows\Fonts\consolai.ttf
# Eras Demi ITC C:\Windows\Fonts\ERASDEMI.TTF
# MV Boli C:\Windows\Fonts\mvboli.ttf
# HCR Dotum C:\Windows\Fonts\HANDotum.ttf
# Lucida Sans Unicode C:\Windows\Fonts\l_10646.ttf
# Lucida Calligraphy C:\Windows\Fonts\LCALLIG.TTF
# HYPost-Medium C:\Windows\Fonts\H2PORM.TTF
# Hancom Hoonminjeongeum_V C:\Windows\Fonts\Hancom HMJE_V.ttf
# Harrington C:\Windows\Fonts\HARNGTON.TTF
# Agency FB C:\Windows\Fonts\AGENCYR.TTF
# Corbel C:\Windows\Fonts\corbelli.ttf
# HYGraphic-Medium C:\Windows\Fonts\H2GPRM.TTF
# Arial C:\Windows\Fonts\arialbi.ttf
# Magic R C:\Windows\Fonts\HMKMMAG.TTF
# Dubai C:\Windows\Fonts\DUBAI-LIGHT.TTF
# Comic Sans MS C:\Windows\Fonts\comici.ttf
# HCR Batang Ext C:\Windows\Fonts\HANBatangExt.ttf
# Bookman Old Style C:\Windows\Fonts\BOOKOSB.TTF
# Playbill C:\Windows\Fonts\PLAYBILL.TTF
# Courier New C:\Windows\Fonts\courbd.ttf
# Copperplate Gothic Light C:\Windows\Fonts\COPRGTL.TTF
# Bodoni MT C:\Windows\Fonts\BOD_CR.TTF
# Segoe UI C:\Windows\Fonts\seguibli.ttf

# %%
import pandas as pd
import numpy as np

# !pip install pykrx
from pykrx import stock

from tqdm import tqdm
import time

import seaborn as sns

# %%
df = pd.read_csv("./meta_data.csv")
df
# Out:
#        종목코드       종목명   시장구분   업종명      종가     대비   등락률             시가총액
# 0    120110     코오롱인더  KOSPI    화학   36550    -50 -0.14    1005822776050
# 1       150        두산  KOSPI  기타금융  137000   4100  3.09    2263765395000
# 2     24720     콜마홀딩스  KOSPI  기타금융    8250     20  0.24     303348540000
# 3     24720     콜마홀딩스  KOSPI  기타금융    8250     20  0.24     303348540000
# 4      4560   현대비앤지스틸  KOSPI  철강금속   20950    600  2.95     315901090450
# ..      ...       ...    ...   ...     ...    ...   ...              ...
# 141    4990      롯데지주  KOSPI  기타금융   26500   -300 -1.12    2780094780500
# 142  267260  HD현대일렉트릭  KOSPI  전기전자  255000  15000  6.25    9192019425000
# 143    1740    SK네트웍스  KOSPI   유통업    5540    -20 -0.36    1225879577080
# 144    5930      삼성전자  KOSPI  전기전자   78600   3100  4.11  469224908430000
# 145    9440   KC그린홀딩스  KOSPI  기타금융    2405      5  0.21      53956126900
#
# [146 rows x 8 columns]

# %%
df['종목코드'] = df['종목코드'].astype(str).str.zfill(6)

# %%
import numpy as np 
from statsmodels import regression
import statsmodels.api as sm 
import matplotlib.pyplot as plt 
import math
import pandas as pd 
import pandas_datareader as pdr

# %%
sector_counts = df.groupby('업종명').size().reset_index(name='종목수')

print(sector_counts)
# Out:
#       업종명  종목수
# 0     건설업    6
# 1      기계    3
# 2    기타금융   20
# 3      보험    4
# 4   비금속광물    4
# 5    서비스업   11
# 6    섬유의복    1
# 7    운수장비   10
# 8   운수창고업    6
# 9     유통업   13
# 10     은행    2
# 11   음식료품    3
# 12    의약품    7
# 13  전기가스업    3
# 14   전기전자   13
# 15   종이목재    2
# 16     증권    5
# 17   철강금속    7
# 18    통신업    2
# 19     화학   24

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import networkx as nx
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import seaborn as sns
import networkx as nx

# %%
def create_graph_with_correlation(df, start, end):
    G = nx.Graph()
    
    # 모든 주식의 종가 데이터 가져오기
    stock_prices = {}
    for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
        code = row["종목코드"]
        name = row["종목명"]
        sector = row["업종명"]
        asset = fdr.DataReader(code, start, end)
        stock_prices[code] = asset['Close']
    
    # 가장 긴 공통 기간 찾기
    min_date = max([prices.index.min() for prices in stock_prices.values()])
    max_date = min([prices.index.max() for prices in stock_prices.values()])
    
    # 공통 기간 내의 데이터를 기준으로 필터링
    common_dates = pd.date_range(start=min_date, end=max_date)
    print(f"Common date range: {min_date} to {max_date}")

    filtered_prices = {}
    for code in stock_prices:
        filtered_prices[code] = stock_prices[code].reindex(common_dates).dropna()
    
    # 시가총액 상위 50개 종목 선택
    valid_codes = [code for code in filtered_prices if len(filtered_prices[code]) > 0]
    top_50_df = df[df['종목코드'].isin(valid_codes)].nlargest(50, '시가총액')

    print(f"Valid codes after filtering: {len(valid_codes)}")
    print(f"Top 50 codes selected: {len(top_50_df)}")

    # 시가총액 상위 50개 종목에 대해 다시 종가 데이터를 가져오기
    stock_prices_top_50 = {code: filtered_prices[code] for code in top_50_df['종목코드']}

    for idx, row in tqdm(top_50_df.iterrows(), total=top_50_df.shape[0]):
        code = row["종목코드"]
        name = row["종목명"]
        sector = row["업종명"]
        
        # 그래프 노드에 종목명과 업종명 추가
        G.add_node(name, sector=sector)
    
    codes = list(stock_prices_top_50.keys())
    edge_count = 0
    for i in range(len(codes)):
        for j in range(i + 1, len(codes)):
            code_i = codes[i]
            code_j = codes[j]
            
            # 두 종목의 종가 데이터 가져오기
            prices_i = stock_prices_top_50[code_i]
            prices_j = stock_prices_top_50[code_j]
            
            # 상관 관계 계산
            if len(prices_i) > 1 and len(prices_j) > 1:  # 최소한 두 개의 데이터 포인트가 있는 경우
                correlation = prices_i.corr(prices_j)
                if not np.isnan(correlation) and correlation > 0.5:  # 상관 관계가 높은 경우만 엣지 추가
                    G.add_edge(df.loc[df['종목코드'] == code_i, '종목명'].values[0], 
                               df.loc[df['종목코드'] == code_j, '종목명'].values[0], 
                               weight=correlation)
                    edge_count += 1
    
    print(f"Total edges added: {edge_count}")
    return G

# %%
start_date = '2020-03-19'
end_date = '2020-05-19'

G = create_graph_with_correlation(df, start_date, end_date)

num_nodes = G.number_of_nodes()

print(f"Number of nodes in the graph: {num_nodes}")
# Out:
# 100%|██████████| 146/146 [02:33<00:00,  1.05s/it]
# Common date range: 2020-03-19 00:00:00 to 2020-05-19 00:00:00
# Valid codes after filtering: 129
# Top 50 codes selected: 50
# 100%|██████████| 50/50 [00:00<?, ?it/s]
# Total edges added: 899
# Number of nodes in the graph: 45

# %%
print("Edge weights:")
for (u, v, weight) in G.edges(data=True):
    print(f"({u}, {v}): {weight['weight']}")
# Out:
# Edge weights:
# (삼성전자, 삼성바이오로직스): 0.684895187570226
# (삼성전자, 기아): 0.7898008889033975
# (삼성전자, LG화학): 0.8223582351995614
# (삼성전자, 포스코퓨처엠): 0.7788834267630104
# (삼성전자, 현대모비스): 0.8687181017073662
# (삼성전자, 신한지주): 0.7940450109087687
# (삼성전자, 삼성생명): 0.8499270118960105
# (삼성전자, 하나금융지주): 0.7500888620688216
# (삼성전자, LG전자): 0.8095669795389139
# (삼성전자, LG): 0.9034967248627571
# (삼성전자, 한화에어로스페이스): 0.7942892146723394
# (삼성전자, SK): 0.8554119971834213
# (삼성전자, 삼성에스디에스): 0.5792675703811703
# (삼성전자, 삼성전기): 0.6542644001824851
# (삼성전자, SK텔레콤): 0.7043467380157732
# (삼성전자, 기업은행): 0.870752259766431
# (삼성전자, SK이노베이션): 0.8972182149017883
# (삼성전자, 우리금융지주): 0.8655632153029099
# (삼성전자, 두산에너빌리티): 0.7998329526787012
# (삼성전자, 고려아연): 0.9091071529811385
# (삼성전자, HD현대일렉트릭): 0.7314332325814098
# (삼성전자, HD한국조선해양): 0.7365314632555816
# (삼성전자, S-Oil): 0.8131947947322085
# (삼성전자, 삼성중공업): 0.8393839890006952
# (삼성전자, 포스코인터내셔널): 0.7721422614503295
# (삼성전자, 대한항공): 0.8504430769325617
# (삼성전자, 한국타이어앤테크놀로지): 0.8126524210455452
# (삼성전자, 현대글로비스): 0.854769540995622
# (삼성전자, LG생활건강): 0.5441654633691027
# (삼성전자, 유한양행): 0.5682786653526469
# (삼성전자, 한국항공우주): 0.830442609116451
# (삼성전자, LG디스플레이): 0.7746953762853351
# (삼성전자, LG이노텍): 0.7588552313399999
# (삼성전자, 현대로템): 0.6162386064386074
# (삼성전자, SKC): 0.7595200293536575
# (삼성전자, 롯데케미칼): 0.7986153338433097
# (삼성전자, LG유플러스): 0.6505156353902446
# (삼성전자, 한화솔루션): 0.7594260986833071
# (삼성전자, 한미약품): 0.6932754803309995
# (삼성전자, 한진칼): 0.6541329913673594
# (삼성전자, NH투자증권): 0.7820509254767541
# (삼성바이오로직스, 기아): 0.8236336653184232
# (삼성바이오로직스, NAVER): 0.8552468449443369
# (삼성바이오로직스, LG화학): 0.9262898708419528
# (삼성바이오로직스, 포스코퓨처엠): 0.9474994693822129
# (삼성바이오로직스, 현대모비스): 0.6479987391296193
# (삼성바이오로직스, 신한지주): 0.7359202633329892
# (삼성바이오로직스, 카카오): 0.8605221144585606
# (삼성바이오로직스, 삼성생명): 0.8104372010104214
# (삼성바이오로직스, 하나금융지주): 0.7835133118908324
# (삼성바이오로직스, LG전자): 0.820421517325762
# (삼성바이오로직스, LG): 0.771000847055067
# (삼성바이오로직스, 한화에어로스페이스): 0.8563457439603653
# (삼성바이오로직스, SK): 0.8316036530067616
# (삼성바이오로직스, 삼성에스디에스): 0.864576822590027
# (삼성바이오로직스, 삼성전기): 0.901458931194178
# (삼성바이오로직스, SK텔레콤): 0.9146195604332465
# (삼성바이오로직스, 기업은행): 0.6569208789252992
# (삼성바이오로직스, SK이노베이션): 0.767400434386749
# (삼성바이오로직스, 우리금융지주): 0.8258216746686879
# (삼성바이오로직스, 두산에너빌리티): 0.7698409450877952
# (삼성바이오로직스, 고려아연): 0.6580055166197243
# (삼성바이오로직스, HD현대일렉트릭): 0.9174621415898783
# (삼성바이오로직스, S-Oil): 0.7755102227177454
# (삼성바이오로직스, 삼성중공업): 0.6689645698199491
# (삼성바이오로직스, 포스코인터내셔널): 0.8327469819931658
# (삼성바이오로직스, 대한항공): 0.5740728256968852
# (삼성바이오로직스, 한국타이어앤테크놀로지): 0.7700538486315464
# (삼성바이오로직스, 현대글로비스): 0.7728348827296275
# (삼성바이오로직스, LG생활건강): 0.9071851090757262
# (삼성바이오로직스, 유한양행): 0.8091267420996826
# (삼성바이오로직스, 한국항공우주): 0.8719999039368711
# (삼성바이오로직스, LG이노텍): 0.9064941024634972
# (삼성바이오로직스, 현대로템): 0.9057126813443656
# (삼성바이오로직스, SKC): 0.946176365897726
# (삼성바이오로직스, 롯데케미칼): 0.7834054333291661
# (삼성바이오로직스, LG유플러스): 0.9165983745249973
# (삼성바이오로직스, 한화솔루션): 0.8523905159772798
# (삼성바이오로직스, 한미약품): 0.6120774049784324
# (삼성바이오로직스, 한진칼): 0.6999564277748074
# (삼성바이오로직스, NH투자증권): 0.7314440339173292
# (기아, NAVER): 0.7057083999702072
# (기아, LG화학): 0.8331869239964402
# (기아, 포스코퓨처엠): 0.8661801563554734
# (기아, 현대모비스): 0.84136926561351
# (기아, 신한지주): 0.8557179806834248
# (기아, 카카오): 0.6741130487261087
# (기아, 삼성생명): 0.848864678108974
# (기아, 하나금융지주): 0.8801798361001897
# (기아, LG전자): 0.9564382882994028
# (기아, LG): 0.8586767081238661
# (기아, 한화에어로스페이스): 0.8726217483299286
# (기아, SK): 0.8947109937090862
# (기아, 삼성에스디에스): 0.8070925574516609
# (기아, 삼성전기): 0.7911845834523261
# (기아, SK텔레콤): 0.8331877684765685
# (기아, 기업은행): 0.8483291281009888
# (기아, SK이노베이션): 0.8925895807605393
# (기아, 우리금융지주): 0.8820588355153003
# (기아, 두산에너빌리티): 0.9043874704953189
# (기아, 고려아연): 0.7921529558730132
# (기아, HD현대일렉트릭): 0.8446822904224183
# (기아, HD한국조선해양): 0.7559779124302896
# (기아, S-Oil): 0.8953268371817942
# (기아, 삼성중공업): 0.9032349811901916
# (기아, 포스코인터내셔널): 0.9485428870491567
# (기아, 대한항공): 0.7731958233433841
# (기아, 한국타이어앤테크놀로지): 0.9604028482682505
# (기아, 현대글로비스): 0.9643079046901786
# (기아, LG생활건강): 0.7372774956234591
# (기아, 유한양행): 0.8597123796834315
# (기아, 한국항공우주): 0.8531690424559727
# (기아, LG디스플레이): 0.530522257512282
# (기아, LG이노텍): 0.8648842503551626
# (기아, 현대로템): 0.7240467959291075
# (기아, SKC): 0.8517659529602474
# (기아, 롯데케미칼): 0.7067896570532557
# (기아, LG유플러스): 0.8600643889180012
# (기아, 한화솔루션): 0.8769842912085053
# (기아, 한미약품): 0.7759274015739855
# (기아, 한진칼): 0.7958262343688315
# (기아, NH투자증권): 0.8529182185862784
# (NAVER, LG화학): 0.7814810638098062
# (NAVER, 포스코퓨처엠): 0.8374729247682796
# (NAVER, 신한지주): 0.735451179282295
# (NAVER, 카카오): 0.9719835596608095
# (NAVER, 삼성생명): 0.5513565506975956
# (NAVER, 하나금융지주): 0.7869304206670514
# (NAVER, LG전자): 0.7765508131652079
# (NAVER, LG): 0.6579245544517955
# (NAVER, 한화에어로스페이스): 0.7573219284449375
# (NAVER, SK): 0.7337413560273474
# (NAVER, 삼성에스디에스): 0.8904478542924609
# (NAVER, 삼성전기): 0.9202231060856946
# (NAVER, SK텔레콤): 0.8229483871386455
# (NAVER, 기업은행): 0.5241140008274822
# (NAVER, SK이노베이션): 0.6392265001447327
# (NAVER, 우리금융지주): 0.6740785919666006
# (NAVER, 두산에너빌리티): 0.6680544121528883
# (NAVER, HD현대일렉트릭): 0.8385488012523431
# (NAVER, S-Oil): 0.668502708868682
# (NAVER, 삼성중공업): 0.5209915485562954
# (NAVER, 포스코인터내셔널): 0.7924889995221829
# (NAVER, 한국타이어앤테크놀로지): 0.6355841198099378
# (NAVER, 현대글로비스): 0.629575758680114
# (NAVER, LG생활건강): 0.9316255246946947
# (NAVER, 유한양행): 0.8278533250678799
# (NAVER, 한국항공우주): 0.7536116503657616
# (NAVER, LG이노텍): 0.8666830193089377
# (NAVER, 현대로템): 0.8741098544340926
# (NAVER, SKC): 0.8283716837339579
# (NAVER, 롯데케미칼): 0.6117003434276281
# (NAVER, LG유플러스): 0.9160279933548902
# (NAVER, 한화솔루션): 0.8199607621710725
# (NAVER, 한미약품): 0.5561379768562592
# (NAVER, 한진칼): 0.5783915033166539
# (NAVER, NH투자증권): 0.7751158130104279
# (LG화학, 포스코퓨처엠): 0.9565612846941779
# (LG화학, 현대모비스): 0.7413029507175805
# (LG화학, 신한지주): 0.8173881046180028
# (LG화학, 카카오): 0.7510561210801698
# (LG화학, 삼성생명): 0.8693761876324475
# (LG화학, 하나금융지주): 0.8443540904250065
# (LG화학, LG전자): 0.8596361369735992
# (LG화학, LG): 0.8515757011393844
# (LG화학, 한화에어로스페이스): 0.9209236354657887
# (LG화학, SK): 0.8732234558965666
# (LG화학, 삼성에스디에스): 0.7892118483677584
# (LG화학, 삼성전기): 0.8655374237929959
# (LG화학, SK텔레콤): 0.9072194031303942
# (LG화학, 기업은행): 0.7706872748549398
# (LG화학, SK이노베이션): 0.8438710485412262
# (LG화학, 우리금융지주): 0.9006604775976311
# (LG화학, 두산에너빌리티): 0.8095279284641538
# (LG화학, 고려아연): 0.7656062783584238
# (LG화학, HD현대일렉트릭): 0.9283866742518554
# (LG화학, HD한국조선해양): 0.5529316438698185
# (LG화학, S-Oil): 0.8166318266818559
# (LG화학, 삼성중공업): 0.7339155935971837
# (LG화학, 포스코인터내셔널): 0.849448285213068
# (LG화학, 대한항공): 0.7102689231630532
# (LG화학, 한국타이어앤테크놀로지): 0.7907906439725209
# (LG화학, 현대글로비스): 0.8209082434565798
# (LG화학, LG생활건강): 0.8303365032478851
# (LG화학, 유한양행): 0.7293409864557756
# (LG화학, 한국항공우주): 0.9355251702962848
# (LG화학, LG이노텍): 0.8909953232082439
# (LG화학, 현대로템): 0.9055231141415098
# (LG화학, SKC): 0.9580268777692824
# (LG화학, 롯데케미칼): 0.8777211275311597
# (LG화학, LG유플러스): 0.8565488099465017
# (LG화학, 한화솔루션): 0.8435080594038488
# (LG화학, 한미약품): 0.6486210746885654
# (LG화학, 한진칼): 0.7445699465017871
# (LG화학, NH투자증권): 0.8174944105250784
# (포스코퓨처엠, 현대모비스): 0.7639951094668019
# (포스코퓨처엠, 신한지주): 0.794751666725309
# (포스코퓨처엠, 카카오): 0.83331821262927
# (포스코퓨처엠, 삼성생명): 0.8066241528516807
# (포스코퓨처엠, 하나금융지주): 0.817485231917772
# (포스코퓨처엠, LG전자): 0.9030942079752533
# (포스코퓨처엠, LG): 0.8660608033713995
# (포스코퓨처엠, 한화에어로스페이스): 0.8933646728867929
# (포스코퓨처엠, SK): 0.9215629227789475
# (포스코퓨처엠, 삼성에스디에스): 0.8600011736736721
# (포스코퓨처엠, 삼성전기): 0.9177600315692666
# (포스코퓨처엠, SK텔레콤): 0.9253740627985998
# (포스코퓨처엠, 기업은행): 0.7299783296387843
# (포스코퓨처엠, SK이노베이션): 0.8519446621487528
# (포스코퓨처엠, 우리금융지주): 0.854309683678878
# (포스코퓨처엠, 두산에너빌리티): 0.8438765167672149
# (포스코퓨처엠, 고려아연): 0.7666982212409198
# (포스코퓨처엠, HD현대일렉트릭): 0.9336656124899531
# (포스코퓨처엠, HD한국조선해양): 0.5163377489671089
# (포스코퓨처엠, S-Oil): 0.847893388857389
# (포스코퓨처엠, 삼성중공업): 0.7532505800406762
# (포스코퓨처엠, 포스코인터내셔널): 0.9004670804225636
# (포스코퓨처엠, 대한항공): 0.6860219178445047
# (포스코퓨처엠, 한국타이어앤테크놀로지): 0.8250833155561758
# (포스코퓨처엠, 현대글로비스): 0.8413345491506856
# (포스코퓨처엠, LG생활건강): 0.8799859470047113
# (포스코퓨처엠, 유한양행): 0.8456924712470167
# (포스코퓨처엠, 한국항공우주): 0.9093834141647166
# (포스코퓨처엠, LG이노텍): 0.9357919990681324
# (포스코퓨처엠, 현대로템): 0.895980901933224
# (포스코퓨처엠, SKC): 0.9829173619657301
# (포스코퓨처엠, 롯데케미칼): 0.8228815423484775
# (포스코퓨처엠, LG유플러스): 0.9264198965615457
# (포스코퓨처엠, 한화솔루션): 0.8967370831904886
# (포스코퓨처엠, 한미약품): 0.6432247613726901
# (포스코퓨처엠, 한진칼): 0.7422505632206451
# (포스코퓨처엠, NH투자증권): 0.8202199072632657
# (현대모비스, 신한지주): 0.8332721931813994
# (현대모비스, 삼성생명): 0.8411072437733241
# (현대모비스, 하나금융지주): 0.737089448867701
# (현대모비스, LG전자): 0.845106993658962
# (현대모비스, LG): 0.9053537794972344
# (현대모비스, 한화에어로스페이스): 0.7323239154091244
# (현대모비스, SK): 0.9172241311751136
# (현대모비스, 삼성에스디에스): 0.5907580278802612
# (현대모비스, 삼성전기): 0.6237014690700579
# (현대모비스, SK텔레콤): 0.6210277970688293
# (현대모비스, 기업은행): 0.9130709501224993
# (현대모비스, SK이노베이션): 0.9513518634073084
# (현대모비스, 우리금융지주): 0.7807750712553986
# (현대모비스, 두산에너빌리티): 0.8943637463569256
# (현대모비스, 고려아연): 0.8952492212982679
# (현대모비스, HD현대일렉트릭): 0.6852412169702755
# (현대모비스, HD한국조선해양): 0.8045580306708362
# (현대모비스, S-Oil): 0.799222239959047
# (현대모비스, 삼성중공업): 0.9037030580622714
# (현대모비스, 포스코인터내셔널): 0.790249339488139
# (현대모비스, 대한항공): 0.9139336259049494
# (현대모비스, 한국타이어앤테크놀로지): 0.8631514284679533
# (현대모비스, 현대글로비스): 0.8742125200345146
# (현대모비스, 유한양행): 0.7187286613052791
# (현대모비스, 한국항공우주): 0.7764033094099785
# (현대모비스, LG디스플레이): 0.7662768628460451
# (현대모비스, LG이노텍): 0.7511065195370331
# (현대모비스, 현대로템): 0.5481231849370177
# (현대모비스, SKC): 0.7319101300340424
# (현대모비스, 롯데케미칼): 0.7341661908821966
# (현대모비스, LG유플러스): 0.6608218655461388
# (현대모비스, 한화솔루션): 0.8503692875902333
# (현대모비스, 한미약품): 0.7552787960824042
# (현대모비스, 한진칼): 0.6697503182993805
# (현대모비스, NH투자증권): 0.8490436476980242
# (신한지주, 카카오): 0.6614493822385241
# (신한지주, 삼성생명): 0.8348058670452164
# (신한지주, 하나금융지주): 0.9576357793355055
# (신한지주, LG전자): 0.894290920110288
# (신한지주, LG): 0.8741658014399136
# (신한지주, 한화에어로스페이스): 0.8557965071525877
# (신한지주, SK): 0.8832151159953499
# (신한지주, 삼성에스디에스): 0.7071788877516738
# (신한지주, 삼성전기): 0.7555709547188558
# (신한지주, SK텔레콤): 0.7198157581161433
# (신한지주, 기업은행): 0.9228409336975816
# (신한지주, SK이노베이션): 0.8887147021714422
# (신한지주, 우리금융지주): 0.8896211096191918
# (신한지주, 두산에너빌리티): 0.8623688019945914
# (신한지주, 고려아연): 0.7360287938556311
# (신한지주, HD현대일렉트릭): 0.7741635310447642
# (신한지주, HD한국조선해양): 0.7546763782379492
# (신한지주, S-Oil): 0.7824865014074259
# (신한지주, 삼성중공업): 0.8127833475884864
# (신한지주, 포스코인터내셔널): 0.8645675827628748
# (신한지주, 대한항공): 0.798579025520579
# (신한지주, 한국타이어앤테크놀로지): 0.8268388999191726
# (신한지주, 현대글로비스): 0.831403723474222
# (신한지주, LG생활건강): 0.6610659979200441
# (신한지주, 유한양행): 0.7619362321831961
# (신한지주, 한국항공우주): 0.8643607071528973
# (신한지주, LG디스플레이): 0.5982506805432295
# (신한지주, LG이노텍): 0.850204787457267
# (신한지주, 현대로템): 0.7086772128458942
# (신한지주, SKC): 0.7676983059949916
# (신한지주, 롯데케미칼): 0.7795078623789937
# (신한지주, LG유플러스): 0.7931690433625356
# (신한지주, 한화솔루션): 0.896948941529907
# (신한지주, 한미약품): 0.7489388863318035
# (신한지주, 한진칼): 0.6735740953060936
# (신한지주, NH투자증권): 0.9555534439503669
# (카카오, 하나금융지주): 0.6969629513841897
# (카카오, LG전자): 0.7407702228288817
# (카카오, LG): 0.6174286929679672
# (카카오, 한화에어로스페이스): 0.6745988645337643
# (카카오, SK): 0.6966117243315617
# (카카오, 삼성에스디에스): 0.911853419065695
# (카카오, 삼성전기): 0.9455370011072061
# (카카오, SK텔레콤): 0.780120669638668
# (카카오, SK이노베이션): 0.5781559063258989
# (카카오, 우리금융지주): 0.6073874752076092
# (카카오, 두산에너빌리티): 0.5985192787836912
# (카카오, HD현대일렉트릭): 0.7798217672381987
# (카카오, S-Oil): 0.5958369413262619
# (카카오, 포스코인터내셔널): 0.7445249056676105
# (카카오, 한국타이어앤테크놀로지): 0.5699357559193321
# (카카오, 현대글로비스): 0.5877501026149938
# (카카오, LG생활건강): 0.9236225096396703
# (카카오, 유한양행): 0.8269806892160985
# (카카오, 한국항공우주): 0.6866532280336439
# (카카오, LG이노텍): 0.8557227479213122
# (카카오, 현대로템): 0.8222149836427589
# (카카오, SKC): 0.821281163444651
# (카카오, 롯데케미칼): 0.5191847323874116
# (카카오, LG유플러스): 0.8933062470527795
# (카카오, 한화솔루션): 0.7916489208872257
# (카카오, NH투자증권): 0.6844264890222154
# (삼성생명, 하나금융지주): 0.8240088029863211
# (삼성생명, LG전자): 0.8118529342778326
# (삼성생명, LG): 0.8490141033641793
# (삼성생명, 한화에어로스페이스): 0.8589913552854958
# (삼성생명, SK): 0.8494218025033087
# (삼성생명, 삼성에스디에스): 0.6130850483008015
# (삼성생명, 삼성전기): 0.6420770761688815
# (삼성생명, SK텔레콤): 0.7597894632460862
# (삼성생명, 기업은행): 0.8907621960092362
# (삼성생명, SK이노베이션): 0.9031093875888181
# (삼성생명, 우리금융지주): 0.8916244138598899
# (삼성생명, 두산에너빌리티): 0.8535101717350456
# (삼성생명, 고려아연): 0.8638845339719688
# (삼성생명, HD현대일렉트릭): 0.7870664086281683
# (삼성생명, HD한국조선해양): 0.6924076644892014
# (삼성생명, S-Oil): 0.8124419575499919
# (삼성생명, 삼성중공업): 0.8487872680587203
# (삼성생명, 포스코인터내셔널): 0.7929396351323186
# (삼성생명, 대한항공): 0.8401854099878308
# (삼성생명, 한국타이어앤테크놀로지): 0.8573533873072873
# (삼성생명, 현대글로비스): 0.8551178659635759
# (삼성생명, LG생활건강): 0.6015439889390306
# (삼성생명, 유한양행): 0.6388478720324047
# (삼성생명, 한국항공우주): 0.8781540027523808
# (삼성생명, LG디스플레이): 0.6550209325839645
# (삼성생명, LG이노텍): 0.7666168628075658
# (삼성생명, 현대로템): 0.7119326295118952
# (삼성생명, SKC): 0.8050769612350875
# (삼성생명, 롯데케미칼): 0.852685149987316
# (삼성생명, LG유플러스): 0.7102750720627561
# (삼성생명, 한화솔루션): 0.7952243798424541
# (삼성생명, 한미약품): 0.7200857928621192
# (삼성생명, 한진칼): 0.748417292112959
# (삼성생명, NH투자증권): 0.7835064122594635
# (하나금융지주, LG전자): 0.9014691507228787
# (하나금융지주, LG): 0.825513080715502
# (하나금융지주, 한화에어로스페이스): 0.9098325265859001
# (하나금융지주, SK): 0.8503325419999411
# (하나금융지주, 삼성에스디에스): 0.7486115860564033
# (하나금융지주, 삼성전기): 0.7737675355151719
# (하나금융지주, SK텔레콤): 0.8151833108920116
# (하나금융지주, 기업은행): 0.8667842007181115
# (하나금융지주, SK이노베이션): 0.8483695917800803
# (하나금융지주, 우리금융지주): 0.9232861255098114
# (하나금융지주, 두산에너빌리티): 0.8657567718613752
# (하나금융지주, 고려아연): 0.7034810988484225
# (하나금융지주, HD현대일렉트릭): 0.8472750089557367
# (하나금융지주, HD한국조선해양): 0.7008081928425001
# (하나금융지주, S-Oil): 0.832039239615876
# (하나금융지주, 삼성중공업): 0.806772613019335
# (하나금융지주, 포스코인터내셔널): 0.9073609906636518
# (하나금융지주, 대한항공): 0.7520297712848201
# (하나금융지주, 한국타이어앤테크놀로지): 0.8526618754179092
# (하나금융지주, 현대글로비스): 0.8436316700131175
# (하나금융지주, LG생활건강): 0.7425411628857806
# (하나금융지주, 유한양행): 0.768441645903611
# (하나금융지주, 한국항공우주): 0.8861176692268523
# (하나금융지주, LG디스플레이): 0.5240862700998027
# (하나금융지주, LG이노텍): 0.8607833596628457
# (하나금융지주, 현대로템): 0.7863853601008388
# (하나금융지주, SKC): 0.8069070872185048
# (하나금융지주, 롯데케미칼): 0.7926900077162101
# (하나금융지주, LG유플러스): 0.8518710237878901
# (하나금융지주, 한화솔루션): 0.8667654282581696
# (하나금융지주, 한미약품): 0.7442592945566727
# (하나금융지주, 한진칼): 0.7530158313535592
# (하나금융지주, NH투자증권): 0.9237422712623736
# (LG전자, LG): 0.8943655833884798
# (LG전자, 한화에어로스페이스): 0.8814709447343198
# (LG전자, SK): 0.9295510439488057
# (LG전자, 삼성에스디에스): 0.811545479321001
# (LG전자, 삼성전기): 0.8432525173974156
# (LG전자, SK텔레콤): 0.8509611986138842
# (LG전자, 기업은행): 0.8478071115656058
# (LG전자, SK이노베이션): 0.9192229316253868
# (LG전자, 우리금융지주): 0.8651961326707452
# (LG전자, 두산에너빌리티): 0.9163913519022575
# (LG전자, 고려아연): 0.8030347730678588
# (LG전자, HD현대일렉트릭): 0.8527844270503613
# (LG전자, HD한국조선해양): 0.7256175949036565
# (LG전자, S-Oil): 0.9129313605160129
# (LG전자, 삼성중공업): 0.8908399356260144
# (LG전자, 포스코인터내셔널): 0.9757852070572396
# (LG전자, 대한항공): 0.7707817079584012
# (LG전자, 한국타이어앤테크놀로지): 0.9246308749124348
# (LG전자, 현대글로비스): 0.9430568633288834
# (LG전자, LG생활건강): 0.7848463765201156
# (LG전자, 유한양행): 0.8600817432925597
# (LG전자, 한국항공우주): 0.877536444299287
# (LG전자, LG이노텍): 0.9050891236253827
# (LG전자, 현대로템): 0.7595149079659461
# (LG전자, SKC): 0.872358855770275
# (LG전자, 롯데케미칼): 0.7170255174825357
# (LG전자, LG유플러스): 0.9005073890209732
# (LG전자, 한화솔루션): 0.9068138316711849
# (LG전자, 한미약품): 0.7415187724927766
# (LG전자, 한진칼): 0.7541944216802091
# (LG전자, NH투자증권): 0.9078939060739624
# (LG, 한화에어로스페이스): 0.8638143478082794
# (LG, SK): 0.9262707827632385
# (LG, 삼성에스디에스): 0.7292340077471227
# (LG, 삼성전기): 0.7575476032777628
# (LG, SK텔레콤): 0.7918564752627103
# (LG, 기업은행): 0.8642876647537219
# (LG, SK이노베이션): 0.9469199746992699
# (LG, 우리금융지주): 0.856702800084037
# (LG, 두산에너빌리티): 0.889040893486623
# (LG, 고려아연): 0.8981034258735183
# (LG, HD현대일렉트릭): 0.8151242689669675
# (LG, HD한국조선해양): 0.6696464351216168
# (LG, S-Oil): 0.8596903000754005
# (LG, 삼성중공업): 0.86685024092313
# (LG, 포스코인터내셔널): 0.8712988343805793
# (LG, 대한항공): 0.8477344653510714
# (LG, 한국타이어앤테크놀로지): 0.8672851411587309
# (LG, 현대글로비스): 0.9005711296054083
# (LG, LG생활건강): 0.6944541573737464
# (LG, 유한양행): 0.7666258314153813
# (LG, 한국항공우주): 0.8955885654015941
# (LG, LG디스플레이): 0.6324564583557616
# (LG, LG이노텍): 0.8671254764863802
# (LG, 현대로템): 0.7233379335177833
# (LG, SKC): 0.8446291859782186
# (LG, 롯데케미칼): 0.816105711043821
# (LG, LG유플러스): 0.8085563811782344
# (LG, 한화솔루션): 0.89570475635207
# (LG, 한미약품): 0.7676676050825966
# (LG, 한진칼): 0.7199422877698232
# (LG, NH투자증권): 0.8824586614102328
# (한화에어로스페이스, SK): 0.8597624025114154
# (한화에어로스페이스, 삼성에스디에스): 0.7428299983152632
# (한화에어로스페이스, 삼성전기): 0.7678004741774433
# (한화에어로스페이스, SK텔레콤): 0.9262446043333212
# (한화에어로스페이스, 기업은행): 0.7824219136371519
# (한화에어로스페이스, SK이노베이션): 0.8635016288650113
# (한화에어로스페이스, 우리금융지주): 0.9089723816852591
# (한화에어로스페이스, 두산에너빌리티): 0.8784140467511047
# (한화에어로스페이스, 고려아연): 0.7890858539290488
# (한화에어로스페이스, HD현대일렉트릭): 0.9381542587399532
# (한화에어로스페이스, HD한국조선해양): 0.575908165256185
# (한화에어로스페이스, S-Oil): 0.8915670883855271
# (한화에어로스페이스, 삼성중공업): 0.8143687473799187
# (한화에어로스페이스, 포스코인터내셔널): 0.9081883512487194
# (한화에어로스페이스, 대한항공): 0.779078055139215
# (한화에어로스페이스, 한국타이어앤테크놀로지): 0.8717783022457153
# (한화에어로스페이스, 현대글로비스): 0.8618404787607667
# (한화에어로스페이스, LG생활건강): 0.8159100227876108
# (한화에어로스페이스, 유한양행): 0.7491809433246248
# (한화에어로스페이스, 한국항공우주): 0.9815048871858467
# (한화에어로스페이스, LG이노텍): 0.8620507989511274
# (한화에어로스페이스, 현대로템): 0.8865713194243287
# (한화에어로스페이스, SKC): 0.9006195990335097
# (한화에어로스페이스, 롯데케미칼): 0.8981222984901692
# (한화에어로스페이스, LG유플러스): 0.8735551421805706
# (한화에어로스페이스, 한화솔루션): 0.8490571281839709
# (한화에어로스페이스, 한미약품): 0.7426805284218976
# (한화에어로스페이스, 한진칼): 0.8214628153225646
# (한화에어로스페이스, NH투자증권): 0.8584156716818294
# (SK, 삼성에스디에스): 0.7625521169746575
# (SK, 삼성전기): 0.809611785377267
# (SK, SK텔레콤): 0.8077429924774718
# (SK, 기업은행): 0.8798905057670067
# (SK, SK이노베이션): 0.9501240224436647
# (SK, 우리금융지주): 0.8689670745275198
# (SK, 두산에너빌리티): 0.9430716668836893
# (SK, 고려아연): 0.8719772051843334
# (SK, HD현대일렉트릭): 0.8437495265410542
# (SK, HD한국조선해양): 0.6885032192799204
# (SK, S-Oil): 0.8589997268114684
# (SK, 삼성중공업): 0.8714594825657156
# (SK, 포스코인터내셔널): 0.9083140016335819
# (SK, 대한항공): 0.8477696735846135
# (SK, 한국타이어앤테크놀로지): 0.8929338853055008
# (SK, 현대글로비스): 0.8883048879591122
# (SK, LG생활건강): 0.710666798159622
# (SK, 유한양행): 0.859397835295631
# (SK, 한국항공우주): 0.8805959541496529
# (SK, LG디스플레이): 0.5894527517507007
# (SK, LG이노텍): 0.8924418191842476
# (SK, 현대로템): 0.7540550958018112
# (SK, SKC): 0.8920215485978278
# (SK, 롯데케미칼): 0.8276112406486509
# (SK, LG유플러스): 0.8534602574764072
# (SK, 한화솔루션): 0.9467362755180679
# (SK, 한미약품): 0.7501887612888513
# (SK, 한진칼): 0.7547687921704315
# (SK, NH투자증권): 0.9116176825774731
# (삼성에스디에스, 삼성전기): 0.9453980741044055
# (삼성에스디에스, SK텔레콤): 0.8209082748869418
# (삼성에스디에스, 기업은행): 0.5802870126610871
# (삼성에스디에스, SK이노베이션): 0.6812684132975526
# (삼성에스디에스, 우리금융지주): 0.7064032579656417
# (삼성에스디에스, 두산에너빌리티): 0.7006793192802052
# (삼성에스디에스, 고려아연): 0.5297128632401968
# (삼성에스디에스, HD현대일렉트릭): 0.8220366765637425
# (삼성에스디에스, S-Oil): 0.6898187546895166
# (삼성에스디에스, 삼성중공업): 0.6093255003660262
# (삼성에스디에스, 포스코인터내셔널): 0.8154143776483539
# (삼성에스디에스, 한국타이어앤테크놀로지): 0.718989115363008
# (삼성에스디에스, 현대글로비스): 0.7449889616561446
# (삼성에스디에스, LG생활건강): 0.8814383974713751
# (삼성에스디에스, 유한양행): 0.8504174437774172
# (삼성에스디에스, 한국항공우주): 0.7437392981823917
# (삼성에스디에스, LG이노텍): 0.8914565702466772
# (삼성에스디에스, 넷마블): 0.5355492110400237
# (삼성에스디에스, 현대로템): 0.8187552777626266
# (삼성에스디에스, SKC): 0.8684781490107317
# (삼성에스디에스, 롯데케미칼): 0.548850747593306
# (삼성에스디에스, LG유플러스): 0.9020420183293898
# (삼성에스디에스, 한화솔루션): 0.8338157207808373
# (삼성에스디에스, 한미약품): 0.6575395168056987
# (삼성에스디에스, 한진칼): 0.6077627326822332
# (삼성에스디에스, NH투자증권): 0.7375319092654793
# (삼성전기, SK텔레콤): 0.8391519702176908
# (삼성전기, 기업은행): 0.6161608626610401
# (삼성전기, SK이노베이션): 0.713916616039999
# (삼성전기, 우리금융지주): 0.7476991733742342
# (삼성전기, 두산에너빌리티): 0.6961257190787852
# (삼성전기, 고려아연): 0.5540707444552421
# (삼성전기, HD현대일렉트릭): 0.8443258360117766
# (삼성전기, S-Oil): 0.704384754303706
# (삼성전기, 삼성중공업): 0.5913124169729632
# (삼성전기, 포스코인터내셔널): 0.8255108733605647
# (삼성전기, 한국타이어앤테크놀로지): 0.6955028866564809
# (삼성전기, 현대글로비스): 0.7322710083924849
# (삼성전기, LG생활건강): 0.9050710396183312
# (삼성전기, 유한양행): 0.8309781405352289
# (삼성전기, 한국항공우주): 0.7893860641112721
# (삼성전기, LG이노텍): 0.9303969204149165
# (삼성전기, 현대로템): 0.8508214480853591
# (삼성전기, SKC): 0.9074193019829447
# (삼성전기, 롯데케미칼): 0.6224076672272251
# (삼성전기, LG유플러스): 0.9120876115103523
# (삼성전기, 한화솔루션): 0.8554213190705678
# (삼성전기, 한미약품): 0.5794577329064501
# (삼성전기, 한진칼): 0.5760207459328986
# (삼성전기, NH투자증권): 0.7686656904375504
# (SK텔레콤, 기업은행): 0.6201042782976397
# (SK텔레콤, SK이노베이션): 0.7747529003049546
# (SK텔레콤, 우리금융지주): 0.8369005856015547
# (SK텔레콤, 두산에너빌리티): 0.8113905780253676
# (SK텔레콤, 고려아연): 0.6924688683119945
# (SK텔레콤, HD현대일렉트릭): 0.9706571425076513
# (SK텔레콤, S-Oil): 0.8762907743940384
# (SK텔레콤, 삼성중공업): 0.7262195969750879
# (SK텔레콤, 포스코인터내셔널): 0.8808607776770022
# (SK텔레콤, 대한항공): 0.6059401712944775
# (SK텔레콤, 한국타이어앤테크놀로지): 0.8162488239167923
# (SK텔레콤, 현대글로비스): 0.8244847005476375
# (SK텔레콤, LG생활건강): 0.9189063908766618
# (SK텔레콤, 유한양행): 0.7583038000097407
# (SK텔레콤, 한국항공우주): 0.9171855555556682
# (SK텔레콤, LG이노텍): 0.8599062640528226
# (SK텔레콤, 현대로템): 0.9429556613051419
# (SK텔레콤, SKC): 0.9446546832147044
# (SK텔레콤, 롯데케미칼): 0.8042133885824163
# (SK텔레콤, LG유플러스): 0.9246196406428201
# (SK텔레콤, 한화솔루션): 0.8063375565217888
# (SK텔레콤, 한미약품): 0.634293540325268
# (SK텔레콤, 한진칼): 0.7445991890813839
# (SK텔레콤, NH투자증권): 0.755752863563902
# (기업은행, SK이노베이션): 0.9240993966809355
# (기업은행, 우리금융지주): 0.8868027495105071
# (기업은행, 두산에너빌리티): 0.8714180337691213
# (기업은행, 고려아연): 0.8557462290481732
# (기업은행, HD현대일렉트릭): 0.6873606226793068
# (기업은행, HD한국조선해양): 0.8813459415196998
# (기업은행, S-Oil): 0.784382666837777
# (기업은행, 삼성중공업): 0.8980430953633884
# (기업은행, 포스코인터내셔널): 0.8083602952189655
# (기업은행, 대한항공): 0.8953407786871118
# (기업은행, 한국타이어앤테크놀로지): 0.8597282544406117
# (기업은행, 현대글로비스): 0.8599863334487623
# (기업은행, 유한양행): 0.6594788414838663
# (기업은행, 한국항공우주): 0.79439993361576
# (기업은행, LG디스플레이): 0.8042434260406011
# (기업은행, LG이노텍): 0.7727479381514311
# (기업은행, 현대로템): 0.5641149025785569
# (기업은행, SKC): 0.6924904647856333
# (기업은행, 롯데케미칼): 0.7675947913401238
# (기업은행, LG유플러스): 0.6676469554668487
# (기업은행, 한화솔루션): 0.8233796703901944
# (기업은행, 한미약품): 0.7751845884472602
# (기업은행, 한진칼): 0.7090851195843663
# (기업은행, NH투자증권): 0.8857357968324737
# (SK이노베이션, 우리금융지주): 0.8608585227910983
# (SK이노베이션, 두산에너빌리티): 0.9426869839897745
# (SK이노베이션, 고려아연): 0.9241721848484591
# (SK이노베이션, HD현대일렉트릭): 0.815349416787946
# (SK이노베이션, HD한국조선해양): 0.7851216810122541
# (SK이노베이션, S-Oil): 0.915994482798013
# (SK이노베이션, 삼성중공업): 0.9426362698620417
# (SK이노베이션, 포스코인터내셔널): 0.896250752938933
# (SK이노베이션, 대한항공): 0.9063388423157606
# (SK이노베이션, 한국타이어앤테크놀로지): 0.9268905310443717
# (SK이노베이션, 현대글로비스): 0.9250800514706596
# (SK이노베이션, LG생활건강): 0.6508273602275758
# (SK이노베이션, 유한양행): 0.7644125289524529
# (SK이노베이션, 한국항공우주): 0.8939507020825632
# (SK이노베이션, LG디스플레이): 0.703242725583417
# (SK이노베이션, LG이노텍): 0.8472064595047241
# (SK이노베이션, 현대로템): 0.7036207398491167
# (SK이노베이션, SKC): 0.8236587005558492
# (SK이노베이션, 롯데케미칼): 0.821890087153052
# (SK이노베이션, LG유플러스): 0.7948122731006361
# (SK이노베이션, 한화솔루션): 0.8928556735401629
# (SK이노베이션, 한미약품): 0.7966783007099439
# (SK이노베이션, 한진칼): 0.7471903836501149
# (SK이노베이션, NH투자증권): 0.9064593856343323
# (우리금융지주, 두산에너빌리티): 0.8520007460923301
# (우리금융지주, 고려아연): 0.7977235981590082
# (우리금융지주, HD현대일렉트릭): 0.8711309857466802
# (우리금융지주, HD한국조선해양): 0.7052062138846592
# (우리금융지주, S-Oil): 0.8366046864324626
# (우리금융지주, 삼성중공업): 0.8307215153456508
# (우리금융지주, 포스코인터내셔널): 0.8595859695744297
# (우리금융지주, 대한항공): 0.7980522266876973
# (우리금융지주, 한국타이어앤테크놀로지): 0.8550007477738611
# (우리금융지주, 현대글로비스): 0.8680772789741598
# (우리금융지주, LG생활건강): 0.6931580655406229
# (우리금융지주, 유한양행): 0.6972910641767068
# (우리금융지주, 한국항공우주): 0.9062309006123187
# (우리금융지주, LG디스플레이): 0.6222235430313413
# (우리금융지주, LG이노텍): 0.838464856357911
# (우리금융지주, 현대로템): 0.7816892629225213
# (우리금융지주, SKC): 0.8498888131920533
# (우리금융지주, 롯데케미칼): 0.8765858768450736
# (우리금융지주, LG유플러스): 0.8007998043179265
# (우리금융지주, 한화솔루션): 0.8445255196096411
# (우리금융지주, 한미약품): 0.717716863213904
# (우리금융지주, 한진칼): 0.7760221117456
# (우리금융지주, NH투자증권): 0.854437477293997
# (두산에너빌리티, 고려아연): 0.871477255292066
# (두산에너빌리티, HD현대일렉트릭): 0.8332399674890683
# (두산에너빌리티, HD한국조선해양): 0.6946981636398704
# (두산에너빌리티, S-Oil): 0.8924117438742576
# (두산에너빌리티, 삼성중공업): 0.9269588238068791
# (두산에너빌리티, 포스코인터내셔널): 0.9121440659909036
# (두산에너빌리티, 대한항공): 0.872919416508991
# (두산에너빌리티, 한국타이어앤테크놀로지): 0.9374368877121779
# (두산에너빌리티, 현대글로비스): 0.9166413719141673
# (두산에너빌리티, LG생활건강): 0.6720617446534694
# (두산에너빌리티, 유한양행): 0.8248105450102443
# (두산에너빌리티, 한국항공우주): 0.8775821788692717
# (두산에너빌리티, LG디스플레이): 0.6139331575628708
# (두산에너빌리티, LG이노텍): 0.8288145130019129
# (두산에너빌리티, 현대로템): 0.7296710536986233
# (두산에너빌리티, SKC): 0.8359856235737373
# (두산에너빌리티, 롯데케미칼): 0.8039352284650823
# (두산에너빌리티, LG유플러스): 0.8323172902948345
# (두산에너빌리티, 한화솔루션): 0.9031672708830165
# (두산에너빌리티, 한미약품): 0.7909227092373766
# (두산에너빌리티, 한진칼): 0.790648681641161
# (두산에너빌리티, NH투자증권): 0.8927444143790659
# (고려아연, HD현대일렉트릭): 0.7068106406822224
# (고려아연, HD한국조선해양): 0.6797588174029155
# (고려아연, S-Oil): 0.8457610956301238
# (고려아연, 삼성중공업): 0.8990403218369349
# (고려아연, 포스코인터내셔널): 0.7763021916258833
# (고려아연, 대한항공): 0.9091115990595321
# (고려아연, 한국타이어앤테크놀로지): 0.8553126987103683
# (고려아연, 현대글로비스): 0.8617808064604795
# (고려아연, 유한양행): 0.6135653315844283
# (고려아연, 한국항공우주): 0.8091451297966656
# (고려아연, LG디스플레이): 0.7571503520337917
# (고려아연, LG이노텍): 0.728997832804493
# (고려아연, 현대로템): 0.5848588443051637
# (고려아연, SKC): 0.7417040271097044
# (고려아연, 롯데케미칼): 0.7925550569820549
# (고려아연, LG유플러스): 0.6611290189701231
# (고려아연, 한화솔루션): 0.7689514826653879
# (고려아연, 한미약품): 0.7462764606944942
# (고려아연, 한진칼): 0.7292314474704704
# (고려아연, NH투자증권): 0.7455620672562341
# (HD현대일렉트릭, S-Oil): 0.8761603690513321
# (HD현대일렉트릭, 삼성중공업): 0.7506555037056704
# (HD현대일렉트릭, 포스코인터내셔널): 0.8776094622870723
# (HD현대일렉트릭, 대한항공): 0.6753713196631104
# (HD현대일렉트릭, 한국타이어앤테크놀로지): 0.8282064312264772
# (HD현대일렉트릭, 현대글로비스): 0.8235440843152725
# (HD현대일렉트릭, LG생활건강): 0.8915389011383924
# (HD현대일렉트릭, 유한양행): 0.7732586968807585
# (HD현대일렉트릭, 한국항공우주): 0.9361677169412578
# (HD현대일렉트릭, LG이노텍): 0.8805590206491104
# (HD현대일렉트릭, 현대로템): 0.9535596929636849
# (HD현대일렉트릭, SKC): 0.9443392487970204
# (HD현대일렉트릭, 롯데케미칼): 0.8657868936681065
# (HD현대일렉트릭, LG유플러스): 0.9130225410420917
# (HD현대일렉트릭, 한화솔루션): 0.845895587158435
# (HD현대일렉트릭, 한미약품): 0.7022570718063991
# (HD현대일렉트릭, 한진칼): 0.7911738886082493
# (HD현대일렉트릭, NH투자증권): 0.8184177481827222
# (HD한국조선해양, S-Oil): 0.6913095457122376
# (HD한국조선해양, 삼성중공업): 0.8390382302460678
# (HD한국조선해양, 포스코인터내셔널): 0.6965812192028158
# (HD한국조선해양, 대한항공): 0.7615152275221447
# (HD한국조선해양, 한국타이어앤테크놀로지): 0.7632360972055905
# (HD한국조선해양, 현대글로비스): 0.770745042851997
# (HD한국조선해양, 유한양행): 0.517726482660838
# (HD한국조선해양, 한국항공우주): 0.5763601572168788
# (HD한국조선해양, LG디스플레이): 0.7984466957142415
# (HD한국조선해양, LG이노텍): 0.5928028659444547
# (HD한국조선해양, 롯데케미칼): 0.5113555073512928
# (HD한국조선해양, 한화솔루션): 0.6191569719763905
# (HD한국조선해양, 한미약품): 0.6684346166447246
# (HD한국조선해양, 한진칼): 0.5638621401955209
# (HD한국조선해양, NH투자증권): 0.7433357325198615
# (S-Oil, 삼성중공업): 0.9194010256832239
# (S-Oil, 포스코인터내셔널): 0.9364755492700689
# (S-Oil, 대한항공): 0.7970282897058651
# (S-Oil, 한국타이어앤테크놀로지): 0.9383071969559499
# (S-Oil, 현대글로비스): 0.9242317910369297
# (S-Oil, LG생활건강): 0.7532181515239735
# (S-Oil, 유한양행): 0.7386509378850159
# (S-Oil, 한국항공우주): 0.8863398496076629
# (S-Oil, LG디스플레이): 0.5376242082705193
# (S-Oil, LG이노텍): 0.8202724373989413
# (S-Oil, 현대로템): 0.7540761924759025
# (S-Oil, SKC): 0.8241236374616038
# (S-Oil, 롯데케미칼): 0.7789432528953761
# (S-Oil, LG유플러스): 0.8488134754396659
# (S-Oil, 한화솔루션): 0.8018299752464022
# (S-Oil, 한미약품): 0.722353543016412
# (S-Oil, 한진칼): 0.7846136738362776
# (S-Oil, NH투자증권): 0.8258938094440241
# (삼성중공업, 포스코인터내셔널): 0.8834230245155523
# (삼성중공업, 대한항공): 0.9001499871938343
# (삼성중공업, 한국타이어앤테크놀로지): 0.9548795398948141
# (삼성중공업, 현대글로비스): 0.9501255995841962
# (삼성중공업, LG생활건강): 0.5588967716405895
# (삼성중공업, 유한양행): 0.706731119817478
# (삼성중공업, 한국항공우주): 0.8107683954210705
# (삼성중공업, LG디스플레이): 0.7195165040609434
# (삼성중공업, LG이노텍): 0.7545057421752518
# (삼성중공업, 현대로템): 0.5964760496319721
# (삼성중공업, SKC): 0.7228276236681879
# (삼성중공업, 롯데케미칼): 0.7269689563586865
# (삼성중공업, LG유플러스): 0.7366055761046733
# (삼성중공업, 한화솔루션): 0.8065483911483694
# (삼성중공업, 한미약품): 0.8048339867445731
# (삼성중공업, 한진칼): 0.7840000636122062
# (삼성중공업, NH투자증권): 0.8495004161359802
# (포스코인터내셔널, 대한항공): 0.7473812974402763
# (포스코인터내셔널, 한국타이어앤테크놀로지): 0.9366490310067103
# (포스코인터내셔널, 현대글로비스): 0.9334450842303618
# (포스코인터내셔널, LG생활건강): 0.8225082733697463
# (포스코인터내셔널, 유한양행): 0.8769375848304563
# (포스코인터내셔널, 한국항공우주): 0.8882726360390316
# (포스코인터내셔널, LG이노텍): 0.9046923371460877
# (포스코인터내셔널, 현대로템): 0.7815467618152191
# (포스코인터내셔널, SKC): 0.8695286581191829
# (포스코인터내셔널, 롯데케미칼): 0.7384303134387131
# (포스코인터내셔널, LG유플러스): 0.924723800553217
# (포스코인터내셔널, 한화솔루션): 0.8838780345093471
# (포스코인터내셔널, 한미약품): 0.7329160068470341
# (포스코인터내셔널, 한진칼): 0.792746437078072
# (포스코인터내셔널, NH투자증권): 0.8900262816464726
# (대한항공, 한국타이어앤테크놀로지): 0.8315359008608042
# (대한항공, 현대글로비스): 0.822737417809775
# (대한항공, 유한양행): 0.609670170122162
# (대한항공, 한국항공우주): 0.7894843070399501
# (대한항공, LG디스플레이): 0.8350169918078874
# (대한항공, LG이노텍): 0.6663517494769678
# (대한항공, 현대로템): 0.518082569232038
# (대한항공, SKC): 0.6613366277301437
# (대한항공, 롯데케미칼): 0.8200699593068022
# (대한항공, LG유플러스): 0.5954931454694841
# (대한항공, 한화솔루션): 0.7783679318591407
# (대한항공, 한미약품): 0.7470020157923313
# (대한항공, 한진칼): 0.786175909091564
# (대한항공, NH투자증권): 0.8132017166734343
# (한국타이어앤테크놀로지, 현대글로비스): 0.9645406077673191
# (한국타이어앤테크놀로지, LG생활건강): 0.6788429057871185
# (한국타이어앤테크놀로지, 유한양행): 0.8035436200670403
# (한국타이어앤테크놀로지, 한국항공우주): 0.8549792786906364
# (한국타이어앤테크놀로지, LG디스플레이): 0.6125414686021342
# (한국타이어앤테크놀로지, LG이노텍): 0.8252998941792137
# (한국타이어앤테크놀로지, 현대로템): 0.6999028492796522
# (한국타이어앤테크놀로지, SKC): 0.8046224771642982
# (한국타이어앤테크놀로지, 롯데케미칼): 0.7426700960523942
# (한국타이어앤테크놀로지, LG유플러스): 0.819781971598392
# (한국타이어앤테크놀로지, 한화솔루션): 0.8395247096596136
# (한국타이어앤테크놀로지, 한미약품): 0.8187538573172295
# (한국타이어앤테크놀로지, 한진칼): 0.8219271486198341
# (한국타이어앤테크놀로지, NH투자증권): 0.8544636950066674
# (현대글로비스, LG생활건강): 0.6920221041100385
# (현대글로비스, 유한양행): 0.7779858036822553
# (현대글로비스, 한국항공우주): 0.8542334248769546
# (현대글로비스, LG디스플레이): 0.6061674276333461
# (현대글로비스, LG이노텍): 0.8324894141324025
# (현대글로비스, 현대로템): 0.6980103041822466
# (현대글로비스, SKC): 0.8285946381740317
# (현대글로비스, 롯데케미칼): 0.7182111629068667
# (현대글로비스, LG유플러스): 0.8238440131659105
# (현대글로비스, 한화솔루션): 0.8484544636366477
# (현대글로비스, 한미약품): 0.7811055942309808
# (현대글로비스, 한진칼): 0.7739925260636283
# (현대글로비스, NH투자증권): 0.8490623412162663
# (LG생활건강, 유한양행): 0.7955682765099095
# (LG생활건강, 한국항공우주): 0.8149300030158577
# (LG생활건강, LG이노텍): 0.86118387803278
# (LG생활건강, 현대로템): 0.906972496235544
# (LG생활건강, SKC): 0.881885535603605
# (LG생활건강, 롯데케미칼): 0.6497606055904586
# (LG생활건강, LG유플러스): 0.9351578861279632
# (LG생활건강, 한화솔루션): 0.7692657362518245
# (LG생활건강, 한미약품): 0.5217496194043935
# (LG생활건강, 한진칼): 0.6008858209289724
# (LG생활건강, NH투자증권): 0.6932297491371822
# (유한양행, 한국항공우주): 0.7427844280246675
# (유한양행, LG이노텍): 0.867676696824579
# (유한양행, 현대로템): 0.6936421950983713
# (유한양행, SKC): 0.8152619475494095
# (유한양행, 롯데케미칼): 0.6002561608022072
# (유한양행, LG유플러스): 0.8939941596217814
# (유한양행, 한화솔루션): 0.9034142569077211
# (유한양행, 한미약품): 0.6664894159536651
# (유한양행, 한진칼): 0.6972919634096902
# (유한양행, NH투자증권): 0.7935450411815005
# (한국항공우주, LG디스플레이): 0.5052540560549279
# (한국항공우주, LG이노텍): 0.8731448352102094
# (한국항공우주, 현대로템): 0.8899085465189741
# (한국항공우주, SKC): 0.9177117625175538
# (한국항공우주, 롯데케미칼): 0.9144672319502222
# (한국항공우주, LG유플러스): 0.8666811160431345
# (한국항공우주, 한화솔루션): 0.87641325757483
# (한국항공우주, 한미약품): 0.7266626719989672
# (한국항공우주, 한진칼): 0.7651869272993391
# (한국항공우주, NH투자증권): 0.864129243211877
# (LG디스플레이, 롯데케미칼): 0.5892374965218506
# (LG디스플레이, 한미약품): 0.6385907874253037
# (LG디스플레이, 한진칼): 0.5248406700294029
# (LG디스플레이, NH투자증권): 0.5802313251999501
# (LG이노텍, 현대로템): 0.8341073994282656
# (LG이노텍, SKC): 0.9023451782326748
# (LG이노텍, 롯데케미칼): 0.7470248512570116
# (LG이노텍, LG유플러스): 0.947207872171248
# (LG이노텍, 한화솔루션): 0.9250876362513442
# (LG이노텍, 한미약품): 0.7372042885289781
# (LG이노텍, 한진칼): 0.7243049933633185
# (LG이노텍, NH투자증권): 0.8463373934867614
# (넷마블, 한미약품): 0.6355803116369503
# (현대로템, SKC): 0.9245937104255672
# (현대로템, 롯데케미칼): 0.8089128492513727
# (현대로템, LG유플러스): 0.8787239484197737
# (현대로템, 한화솔루션): 0.7801890377298635
# (현대로템, 한미약품): 0.6145366171066937
# (현대로템, 한진칼): 0.6681205525191375
# (현대로템, NH투자증권): 0.7491701791517468
# (SKC, 롯데케미칼): 0.8231170833291008
# (SKC, LG유플러스): 0.9082089998257287
# (SKC, 한화솔루션): 0.8807068341581046
# (SKC, 한미약품): 0.6347493741992344
# (SKC, 한진칼): 0.7295575706406047
# (SKC, NH투자증권): 0.7940413820276137
# (롯데케미칼, LG유플러스): 0.7169450298145871
# (롯데케미칼, 한화솔루션): 0.7778708960042671
# (롯데케미칼, 한미약품): 0.6482120787388624
# (롯데케미칼, 한진칼): 0.763269479900217
# (롯데케미칼, NH투자증권): 0.7847821858535204
# (LG유플러스, 한화솔루션): 0.9044093070168833
# (LG유플러스, 한미약품): 0.6886699368129079
# (LG유플러스, 한진칼): 0.7177852541254368
# (LG유플러스, NH투자증권): 0.8188178204405963
# (한화솔루션, 한미약품): 0.7650506771443073
# (한화솔루션, 한진칼): 0.729096527059674
# (한화솔루션, NH투자증권): 0.9113506927129593
# (한미약품, 한진칼): 0.7458329515069254
# (한미약품, NH투자증권): 0.7814271105703099
# (한진칼, NH투자증권): 0.7345646295652107

# %%
font_path = "C:/Windows/Fonts/malgun.ttf"  # 폰트 파일 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# %%
sectors = pd.unique(df["업종명"])
color_map = plt.get_cmap('tab20', len(sectors))
sector_color = {sector: color_map(i) for i, sector in enumerate(sectors)}

node_colors = [sector_color[G.nodes[node]['sector']] for node in G.nodes]

legend_patches = [mpatches.Patch(color=sector_color[sector], label=sector) for sector in sectors]

plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G, k=2)  # k 값을 조정하여 노드 간 거리 조정
weights = nx.get_edge_attributes(G, 'weight').values()

# 라벨 위치 조정
labels = {node: node for node in G.nodes}
nx.draw(G, pos, with_labels=False, node_color=node_colors, edge_color='lightgray', width=list(weights))
for p in pos:  # 라벨을 노드 옆에 배치
    pos[p][0] += 0.05
nx.draw_networkx_labels(G, pos, labels, font_family=font_prop.get_name(), font_size=8)

plt.title('Graph with Correlation as Edge Weights', fontproperties=font_prop)
plt.legend(handles=legend_patches, loc='best', title='업종명', prop=font_prop)
plt.show()

# %% [markdown]
# # MST

# %%
mst = nx.minimum_spanning_tree(G)

# %%
plt.figure(figsize=(15, 10))  
pos = nx.planar_layout(mst)  # 엣지 교차를 줄이기 위해 planar_layout 사용

nx.draw(mst, pos, with_labels=False, node_color=node_colors, edge_color='blue', width=2, node_size=300)
nx.draw_networkx_labels(mst, pos, labels={node: node for node in mst.nodes()}, font_family=font_prop.get_name(), font_size=8)
plt.title("Minimun Spanning Tree", fontproperties=font_prop)
plt.legend(handles=legend_patches, loc='best', title='업종명', prop=font_prop)
plt.show()

# %% [markdown]
# # Centrality Analysis

# %%
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G)

# %%
centrality_df = pd.DataFrame({
    '종목코드': list(G.nodes),
    '업종명': [G.nodes[node]['sector'] for node in G.nodes],
    'Degree Centrality': [degree_centrality[node] for node in G.nodes],
    'Betweenness Centrality': [betweenness_centrality[node] for node in G.nodes],
    'Closeness Centrality': [closeness_centrality[node] for node in G.nodes],
    'Eigenvector Centrality': [eigenvector_centrality[node] for node in G.nodes]
})

# %%
for centrality in ['Degree Centrality', 'Betweenness Centrality', 'Closeness Centrality', 'Eigenvector Centrality']:
    print(f"Top 10 {centrality}")
    display(centrality_df[['종목코드', '업종명', centrality]].nlargest(10, centrality))
    print("\n")
# Out:
# Top 10 Degree Centrality
#            종목코드   업종명  Degree Centrality
# 2            기아  운수장비           0.977273
# 7          신한지주  기타금융           0.977273
# 10       하나금융지주  기타금융           0.977273
# 12           LG  기타금융           0.977273
# 14           SK  기타금융           0.977273
# 19      SK이노베이션    화학           0.977273
# 20       우리금융지주  기타금융           0.977273
# 21      두산에너빌리티    기계           0.977273
# 25        S-Oil    화학           0.977273
# 29  한국타이어앤테크놀로지    화학           0.977273
# Top 10 Betweenness Centrality
#        종목코드   업종명  Betweenness Centrality
# 42     한미약품   의약품                0.024747
# 15  삼성에스디에스  서비스업                0.021592
# 2        기아  운수장비                0.001923
# 7      신한지주  기타금융                0.001923
# 10   하나금융지주  기타금융                0.001923
# 12       LG  기타금융                0.001923
# 14       SK  기타금융                0.001923
# 19  SK이노베이션    화학                0.001923
# 20   우리금융지주  기타금융                0.001923
# 21  두산에너빌리티    기계                0.001923
# Top 10 Closeness Centrality
#            종목코드   업종명  Closeness Centrality
# 2            기아  운수장비              0.977778
# 7          신한지주  기타금융              0.977778
# 10       하나금융지주  기타금융              0.977778
# 12           LG  기타금융              0.977778
# 14           SK  기타금융              0.977778
# 19      SK이노베이션    화학              0.977778
# 20       우리금융지주  기타금융              0.977778
# 21      두산에너빌리티    기계              0.977778
# 25        S-Oil    화학              0.977778
# 29  한국타이어앤테크놀로지    화학              0.977778
# Top 10 Eigenvector Centrality
#            종목코드   업종명  Eigenvector Centrality
# 2            기아  운수장비                0.157111
# 7          신한지주  기타금융                0.157111
# 10       하나금융지주  기타금융                0.157111
# 12           LG  기타금융                0.157111
# 14           SK  기타금융                0.157111
# 19      SK이노베이션    화학                0.157111
# 20       우리금융지주  기타금융                0.157111
# 21      두산에너빌리티    기계                0.157111
# 25        S-Oil    화학                0.157111
# 29  한국타이어앤테크놀로지    화학                0.157111

# %% [markdown]
# # Influence Maximization

# %%
import random

# 독립적 연접 모델을 사용한 영향 평가 함수
def independent_cascade(G, seed_nodes, steps=1000):
    influenced_nodes = set(seed_nodes)
    new_active = set(seed_nodes)
    for _ in range(steps):
        if not new_active:
            break
        next_active = set()
        for node in new_active:
            for neighbor in G.neighbors(node):
                if neighbor not in influenced_nodes and random.random() < G[node][neighbor]['weight']:
                    next_active.add(neighbor)
        influenced_nodes.update(next_active)
        new_active = next_active
    return len(influenced_nodes)

# %%
# Greedy Algorithm을 사용한 시드 노드 선택
def greedy_algorithm(G, k, steps=1000):
    seed_nodes = []
    for _ in tqdm(range(k)):
        best_node = None
        max_influence = -1
        for node in tqdm(G.nodes):
            if node not in seed_nodes:
                influence = independent_cascade(G, seed_nodes + [node], steps)
                if influence > max_influence:
                    best_node = node
                    max_influence = influence
        seed_nodes.append(best_node)
    return seed_nodes

# %%
# 시드 노드 수 설정
k = 1

# Greedy Algorithm을 사용하여 시드 노드 선택
seed_nodes = greedy_algorithm(G, k)
print(f"Selected seed nodes: {seed_nodes}")
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 1872.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 35.64it/s]
# Selected seed nodes: ['삼성전자']

# %%
font_path = "C:/Windows/Fonts/malgun.ttf"  # 폰트 파일 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# 시각화 (선택된 시드 노드를 강조하여 표시)
pos = nx.spring_layout(G, k=2)
node_colors = ['red' if node in seed_nodes else 'skyblue' for node in G.nodes]

plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, node_color=node_colors, edge_color='gray', node_size=300, font_size=8, font_family=font_prop.get_name())  # 노드 크기 조정
plt.title("Influence Maximization", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Community Detection

# %%
import community as community_louvain

partition = community_louvain.best_partition(G)

# 커뮤니티별로 노드 색상 지정
colors = [partition[node] for node in G.nodes()]

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 폰트 파일 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# 그래프 시각화
pos = nx.spring_layout(G, k=2)
plt.figure(figsize=(12, 8))

nx.draw(G, pos, node_color=colors, with_labels=True, cmap=plt.cm.rainbow, node_size=100, edge_color='lightgray', font_size=8, font_family=font_prop.get_name())
plt.title("Community Detection", fontproperties=font_prop)

plt.show()

# %%
community_df = pd.DataFrame.from_dict(partition, orient='index', columns=['커뮤니티'])
community_df['종목명'] = community_df.index
community_df.reset_index(drop=True, inplace=True)

# 업종명 추가
community_df = community_df.merge(df[['종목명', '업종명']], on='종목명')

# 커뮤니티와 업종명 카운트 피벗 테이블 생성
pivot_table = community_df.pivot_table(index='커뮤니티', columns='업종명', aggfunc='size', fill_value=0)

# 커뮤니티 이름을 "community 1", "community 2" 형식으로 변경
pivot_table.index = [f"community {i+1}" for i in range(len(pivot_table))]

pivot_table
# Out:
# 업종명          기계  기타금융  보험  서비스업  운수장비  운수창고업  유통업  은행  의약품  전기전자  증권  철강금속  \
# community 1   1     6   1     1     3      4    0   1    1     2   1     1
# community 2   0     0   0     4     4      0    1   0    2     6   0     0
#
# 업종명          통신업  화학
# community 1    0   4
# community 2    2   5
