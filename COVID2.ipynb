# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 시스템에 설치된 폰트 목록 출력
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    print(fm.FontProperties(fname=font).get_name(), font)
# Out:
# Microsoft YaHei C:\Windows\Fonts\msyh.ttc
# Ebrima C:\Windows\Fonts\ebrimabd.ttf
# Symbol C:\Windows\Fonts\symbol.ttf
# Cascadia Code C:\Windows\Fonts\CascadiaCode.ttf
# Segoe UI C:\Windows\Fonts\segoeuil.ttf
# Lucida Fax C:\Windows\Fonts\LFAXD.TTF
# Trebuchet MS C:\Windows\Fonts\trebucbi.ttf
# Franklin Gothic Book C:\Windows\Fonts\FRABKIT.TTF
# Lucida Sans C:\Windows\Fonts\LSANSI.TTF
# Leelawadee C:\Windows\Fonts\LEELAWAD.TTF
# Gadugi C:\Windows\Fonts\gadugi.ttf
# Segoe UI Symbol C:\Windows\Fonts\seguisym.ttf
# Segoe UI C:\Windows\Fonts\segoeuii.ttf
# Berlin Sans FB C:\Windows\Fonts\BRLNSR.TTF
# Consolas C:\Windows\Fonts\consola.ttf
# Garamond C:\Windows\Fonts\GARA.TTF
# Constantia C:\Windows\Fonts\constan.ttf
# HYPost-Medium C:\Windows\Fonts\H2PORM.TTF
# Bookman Old Style C:\Windows\Fonts\BOOKOS.TTF
# Microsoft JhengHei C:\Windows\Fonts\msjh.ttc
# Times New Roman C:\Windows\Fonts\timesi.ttf
# Hancom Gothic C:\Windows\Fonts\Hancom Gothic Bold.ttf
# Tempus Sans ITC C:\Windows\Fonts\TEMPSITC.TTF
# Tw Cen MT Condensed C:\Windows\Fonts\TCCM____.TTF
# Lucida Bright C:\Windows\Fonts\LBRITEI.TTF
# Times New Roman C:\Windows\Fonts\timesbi.ttf
# Informal Roman C:\Windows\Fonts\INFROMAN.TTF
# Yu Gothic C:\Windows\Fonts\YuGothR.ttc
# Headline R C:\Windows\Fonts\HMKMRHD.TTF
# Vladimir Script C:\Windows\Fonts\VLADIMIR.TTF
# Jokerman C:\Windows\Fonts\JOKERMAN.TTF
# Franklin Gothic Medium C:\Windows\Fonts\framd.ttf
# Gill Sans Ultra Bold C:\Windows\Fonts\GILSANUB.TTF
# Century Schoolbook C:\Windows\Fonts\SCHLBKB.TTF
# Pyunji R C:\Windows\Fonts\HMFMPYUN.TTF
# MS Reference Specialty C:\Windows\Fonts\REFSPCL.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Corbel C:\Windows\Fonts\corbeli.ttf
# Bauhaus 93 C:\Windows\Fonts\BAUHS93.TTF
# Candara C:\Windows\Fonts\Candarab.ttf
# Goudy Old Style C:\Windows\Fonts\GOUDOSB.TTF
# Perpetua Titling MT C:\Windows\Fonts\PERTILI.TTF
# Eras Demi ITC C:\Windows\Fonts\ERASDEMI.TTF
# Dubai C:\Windows\Fonts\DUBAI-BOLD.TTF
# Microsoft JhengHei C:\Windows\Fonts\msjhl.ttc
# Franklin Gothic Demi C:\Windows\Fonts\FRADM.TTF
# Copperplate Gothic Bold C:\Windows\Fonts\COPRGTB.TTF
# Georgia C:\Windows\Fonts\georgia.ttf
# Rockwell C:\Windows\Fonts\ROCKI.TTF
# Blackadder ITC C:\Windows\Fonts\ITCBLKAD.TTF
# Edwardian Script ITC C:\Windows\Fonts\ITCEDSCR.TTF
# Georgia C:\Windows\Fonts\georgiab.ttf
# Book Antiqua C:\Windows\Fonts\ANTQUABI.TTF
# SimSun C:\Windows\Fonts\simsun.ttc
# Palatino Linotype C:\Windows\Fonts\palai.ttf
# MT Extra C:\Windows\Fonts\MTEXTRA.TTF
# Verdana C:\Windows\Fonts\verdana.ttf
# Engravers MT C:\Windows\Fonts\ENGR.TTF
# High Tower Text C:\Windows\Fonts\HTOWERTI.TTF
# HYMyeongJo-Extra C:\Windows\Fonts\H2MJRE.TTF
# Segoe UI C:\Windows\Fonts\seguibl.ttf
# Century Schoolbook C:\Windows\Fonts\SCHLBKI.TTF
# Segoe UI C:\Windows\Fonts\seguisbi.ttf
# HCR Dotum Ext C:\Windows\Fonts\HANDotumExt.ttf
# Palatino Linotype C:\Windows\Fonts\pala.ttf
# Bell MT C:\Windows\Fonts\BELLB.TTF
# Microsoft Sans Serif C:\Windows\Fonts\micross.ttf
# Mistral C:\Windows\Fonts\MISTRAL.TTF
# Elephant C:\Windows\Fonts\ELEPHNT.TTF
# Forte C:\Windows\Fonts\FORTE.TTF
# Copperplate Gothic Light C:\Windows\Fonts\COPRGTL.TTF
# Sans Serif Collection C:\Windows\Fonts\SansSerifCollection.ttf
# Constantia C:\Windows\Fonts\constanb.ttf
# HYGungSo-Bold C:\Windows\Fonts\H2GSRB.TTF
# Candara C:\Windows\Fonts\Candaraz.ttf
# Monotype Corsiva C:\Windows\Fonts\MTCORSVA.TTF
# Microsoft New Tai Lue C:\Windows\Fonts\ntailub.ttf
# Segoe UI Variable C:\Windows\Fonts\SegUIVar.ttf
# Cooper Black C:\Windows\Fonts\COOPBL.TTF
# Cambria C:\Windows\Fonts\cambriai.ttf
# Tw Cen MT C:\Windows\Fonts\TCB_____.TTF
# Harlow Solid Italic C:\Windows\Fonts\HARLOWSI.TTF
# Rockwell C:\Windows\Fonts\ROCKB.TTF
# Corbel C:\Windows\Fonts\corbelb.ttf
# Corbel C:\Windows\Fonts\corbel.ttf
# Segoe Script C:\Windows\Fonts\segoesc.ttf
# Myanmar Text C:\Windows\Fonts\mmrtextb.ttf
# Lucida Fax C:\Windows\Fonts\LFAX.TTF
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-Light.ttf
# Gill Sans MT C:\Windows\Fonts\GILB____.TTF
# Century Schoolbook C:\Windows\Fonts\SCHLBKBI.TTF
# Calisto MT C:\Windows\Fonts\CALISTI.TTF
# Tw Cen MT C:\Windows\Fonts\TCMI____.TTF
# Arial C:\Windows\Fonts\ariblk.ttf
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPEB.TTF
# Myanmar Text C:\Windows\Fonts\mmrtext.ttf
# Dubai C:\Windows\Fonts\DUBAI-LIGHT.TTF
# HYPMokGak-Bold C:\Windows\Fonts\H2MKPB.TTF
# MingLiU-ExtB C:\Windows\Fonts\mingliub.ttc
# High Tower Text C:\Windows\Fonts\HTOWERT.TTF
# Comic Sans MS C:\Windows\Fonts\comici.ttf
# Lucida Sans C:\Windows\Fonts\LSANSDI.TTF
# Franklin Gothic Medium C:\Windows\Fonts\framdit.ttf
# New Gulim C:\Windows\Fonts\NGULIM.TTF
# Harrington C:\Windows\Fonts\HARNGTON.TTF
# Microsoft PhagsPa C:\Windows\Fonts\phagspab.ttf
# Californian FB C:\Windows\Fonts\CALIFR.TTF
# Lucida Bright C:\Windows\Fonts\LBRITEDI.TTF
# Consolas C:\Windows\Fonts\consolaz.ttf
# Poor Richard C:\Windows\Fonts\POORICH.TTF
# Segoe UI C:\Windows\Fonts\segoeui.ttf
# Bodoni MT C:\Windows\Fonts\BOD_I.TTF
# Han Santteut Dotum C:\Windows\Fonts\HanSantteutDotum-Regular.ttf
# Old English Text MT C:\Windows\Fonts\OLDENGL.TTF
# Lucida Fax C:\Windows\Fonts\LFAXDI.TTF
# Lucida Sans C:\Windows\Fonts\LSANS.TTF
# Candara C:\Windows\Fonts\Candarai.ttf
# Times New Roman C:\Windows\Fonts\timesbd.ttf
# HCR Batang ExtB C:\Windows\Fonts\HANBatangExtBB.ttf
# Microsoft JhengHei C:\Windows\Fonts\msjhbd.ttc
# Goudy Stout C:\Windows\Fonts\GOUDYSTO.TTF
# Courier New C:\Windows\Fonts\couri.ttf
# Franklin Gothic Book C:\Windows\Fonts\FRABK.TTF
# Lucida Bright C:\Windows\Fonts\LBRITE.TTF
# Eras Medium ITC C:\Windows\Fonts\ERASMD.TTF
# MoeumT R C:\Windows\Fonts\HMFMMUEX.TTC
# Modern No. 20 C:\Windows\Fonts\MOD20.TTF
# Microsoft YaHei C:\Windows\Fonts\msyhbd.ttc
# Curlz MT C:\Windows\Fonts\CURLZ___.TTF
# Chiller C:\Windows\Fonts\CHILLER.TTF
# Trebuchet MS C:\Windows\Fonts\trebucit.ttf
# Palatino Linotype C:\Windows\Fonts\palab.ttf
# Microsoft Tai Le C:\Windows\Fonts\taile.ttf
# Century Gothic C:\Windows\Fonts\GOTHICBI.TTF
# Arial C:\Windows\Fonts\arialbi.ttf
# HYGothic-Medium C:\Windows\Fonts\H2GTRM.TTF
# Agency FB C:\Windows\Fonts\AGENCYB.TTF
# HCR Batang C:\Windows\Fonts\HANBatang.ttf
# Kunstler Script C:\Windows\Fonts\KUNSTLER.TTF
# Niagara Engraved C:\Windows\Fonts\NIAGENG.TTF
# Corbel C:\Windows\Fonts\corbelli.ttf
# Bookman Old Style C:\Windows\Fonts\BOOKOSI.TTF
# Arial C:\Windows\Fonts\arial.ttf
# HCR Dotum C:\Windows\Fonts\HANDotum.ttf
# Ravie C:\Windows\Fonts\RAVIE.TTF
# Lucida Calligraphy C:\Windows\Fonts\LCALLIG.TTF
# Goudy Old Style C:\Windows\Fonts\GOUDOS.TTF
# Trebuchet MS C:\Windows\Fonts\trebuc.ttf
# Microsoft PhagsPa C:\Windows\Fonts\phagspa.ttf
# HYShortSamul-Medium C:\Windows\Fonts\H2SA1M.TTF
# Courier New C:\Windows\Fonts\courbi.ttf
# Bodoni MT C:\Windows\Fonts\BOD_BI.TTF
# Niagara Solid C:\Windows\Fonts\NIAGSOL.TTF
# Script MT Bold C:\Windows\Fonts\SCRIPTBL.TTF
# Javanese Text C:\Windows\Fonts\javatext.ttf
# Hancom Gothic C:\Windows\Fonts\Hancom Gothic Regular.ttf
# Matura MT Script Capitals C:\Windows\Fonts\MATURASC.TTF
# Felix Titling C:\Windows\Fonts\FELIXTI.TTF
# Bodoni MT C:\Windows\Fonts\BOD_B.TTF
# Han Santteut Dotum C:\Windows\Fonts\HanSantteutDotum-Bold.ttf
# Franklin Gothic Demi C:\Windows\Fonts\FRADMIT.TTF
# Malgun Gothic C:\Windows\Fonts\malgun.ttf
# HCR Dotum C:\Windows\Fonts\HANDotumB.ttf
# Segoe UI C:\Windows\Fonts\segoeuib.ttf
# MS Gothic C:\Windows\Fonts\msgothic.ttc
# Maiandra GD C:\Windows\Fonts\MAIAN.TTF
# Perpetua C:\Windows\Fonts\PERBI___.TTF
# Bernard MT Condensed C:\Windows\Fonts\BERNHC.TTF
# Calibri C:\Windows\Fonts\calibrii.ttf
# SimSun-ExtB C:\Windows\Fonts\simsunb.ttf
# Centaur C:\Windows\Fonts\CENTAUR.TTF
# Microsoft Himalaya C:\Windows\Fonts\himalaya.ttf
# Gloucester MT Extra Condensed C:\Windows\Fonts\GLECB.TTF
# Freestyle Script C:\Windows\Fonts\FREESCPT.TTF
# HoloLens MDL2 Assets C:\Windows\Fonts\holomdl2.ttf
# Papyrus C:\Windows\Fonts\PAPYRUS.TTF
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-Regular.ttf
# HYPost-Light C:\Windows\Fonts\H2PORL.TTF
# Pristina C:\Windows\Fonts\PRISTINA.TTF
# Century C:\Windows\Fonts\CENTURY.TTF
# Gill Sans MT Condensed C:\Windows\Fonts\GILC____.TTF
# Microsoft Tai Le C:\Windows\Fonts\taileb.ttf
# HyhwpEQ C:\Windows\Fonts\HYHWPEQ.TTF
# HancomEQN C:\Windows\Fonts\HancomEQN.ttf
# Rockwell Condensed C:\Windows\Fonts\ROCC____.TTF
# Colonna MT C:\Windows\Fonts\COLONNA.TTF
# MS Reference Sans Serif C:\Windows\Fonts\REFSAN.TTF
# Nirmala UI C:\Windows\Fonts\Nirmala.ttf
# Leelawadee UI C:\Windows\Fonts\LeelawUI.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Rockwell C:\Windows\Fonts\ROCK.TTF
# Bookman Old Style C:\Windows\Fonts\BOOKOSB.TTF
# Stencil C:\Windows\Fonts\STENCIL.TTF
# Bell MT C:\Windows\Fonts\BELL.TTF
# French Script MT C:\Windows\Fonts\FRSCRIPT.TTF
# Tw Cen MT C:\Windows\Fonts\TCBI____.TTF
# Wingdings 2 C:\Windows\Fonts\WINGDNG2.TTF
# MS Outlook C:\Windows\Fonts\OUTLOOK.TTF
# Californian FB C:\Windows\Fonts\CALIFI.TTF
# Arial C:\Windows\Fonts\arialbd.ttf
# Cambria C:\Windows\Fonts\cambria.ttc
# Cambria C:\Windows\Fonts\cambriaz.ttf
# Californian FB C:\Windows\Fonts\CALIFB.TTF
# Segoe Fluent Icons C:\Windows\Fonts\SegoeIcons.ttf
# Mongolian Baiti C:\Windows\Fonts\monbaiti.ttf
# Comic Sans MS C:\Windows\Fonts\comicz.ttf
# Bodoni MT C:\Windows\Fonts\BOD_CB.TTF
# Garamond C:\Windows\Fonts\GARABD.TTF
# Magic R C:\Windows\Fonts\HMKMMAG.TTF
# Hancom MalangMalang C:\Windows\Fonts\MalangmalangB.ttf
# Lucida Fax C:\Windows\Fonts\LFAXI.TTF
# Nirmala UI C:\Windows\Fonts\NirmalaB.ttf
# Bodoni MT C:\Windows\Fonts\BOD_CR.TTF
# Perpetua C:\Windows\Fonts\PER_____.TTF
# Microsoft Yi Baiti C:\Windows\Fonts\msyi.ttf
# Verdana C:\Windows\Fonts\verdanaz.ttf
# OCR A Extended C:\Windows\Fonts\OCRAEXT.TTF
# Trebuchet MS C:\Windows\Fonts\trebucbd.ttf
# Rage Italic C:\Windows\Fonts\RAGE.TTF
# Constantia C:\Windows\Fonts\constanz.ttf
# Arial C:\Windows\Fonts\ARIALNBI.TTF
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPE.TTF
# Gill Sans MT Ext Condensed Bold C:\Windows\Fonts\GLSNECB.TTF
# Britannic Bold C:\Windows\Fonts\BRITANIC.TTF
# Imprint MT Shadow C:\Windows\Fonts\IMPRISHA.TTF
# Segoe UI C:\Windows\Fonts\segoeuisl.ttf
# Ink Free C:\Windows\Fonts\Inkfree.ttf
# Berlin Sans FB C:\Windows\Fonts\BRLNSB.TTF
# Segoe UI C:\Windows\Fonts\segoeuiz.ttf
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPEO.TTF
# Ami R C:\Windows\Fonts\HMKMAMI.TTF
# Calisto MT C:\Windows\Fonts\CALISTB.TTF
# Bodoni MT C:\Windows\Fonts\BOD_CBI.TTF
# Microsoft Uighur C:\Windows\Fonts\MSUIGHUR.TTF
# Book Antiqua C:\Windows\Fonts\BKANT.TTF
# Footlight MT Light C:\Windows\Fonts\FTLTLT.TTF
# Franklin Gothic Demi Cond C:\Windows\Fonts\FRADMCN.TTF
# Cambria C:\Windows\Fonts\cambriab.ttf
# Candara C:\Windows\Fonts\Candaral.ttf
# Verdana C:\Windows\Fonts\verdanai.ttf
# Gill Sans MT C:\Windows\Fonts\GIL_____.TTF
# Georgia C:\Windows\Fonts\georgiai.ttf
# Hancom Hoonminjeongeum_V C:\Windows\Fonts\Hancom HMJE_V.ttf
# Arial Rounded MT Bold C:\Windows\Fonts\ARLRDBD.TTF
# Eras Bold ITC C:\Windows\Fonts\ERASBD.TTF
# Gadugi C:\Windows\Fonts\gadugib.ttf
# Palatino Linotype C:\Windows\Fonts\palabi.ttf
# Courier New C:\Windows\Fonts\courbd.ttf
# Sitka C:\Windows\Fonts\SitkaVF-Italic.ttf
# Leelawadee UI C:\Windows\Fonts\LeelaUIb.ttf
# Gulim C:\Windows\Fonts\gulim.ttc
# Berlin Sans FB Demi C:\Windows\Fonts\BRLNSDB.TTF
# Bahnschrift C:\Windows\Fonts\bahnschrift.ttf
# Wingdings 3 C:\Windows\Fonts\WINGDNG3.TTF
# Book Antiqua C:\Windows\Fonts\ANTQUAB.TTF
# Arial C:\Windows\Fonts\ARIALNI.TTF
# Franklin Gothic Medium Cond C:\Windows\Fonts\FRAMDCN.TTF
# Lucida Sans C:\Windows\Fonts\LSANSD.TTF
# Segoe UI C:\Windows\Fonts\seguisb.ttf
# Gill Sans MT C:\Windows\Fonts\GILBI___.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Baskerville Old Face C:\Windows\Fonts\BASKVILL.TTF
# Sylfaen C:\Windows\Fonts\sylfaen.ttf
# Segoe UI Historic C:\Windows\Fonts\seguihis.ttf
# Consolas C:\Windows\Fonts\consolai.ttf
# Eras Light ITC C:\Windows\Fonts\ERASLGHT.TTF
# Constantia C:\Windows\Fonts\constani.ttf
# Nirmala UI C:\Windows\Fonts\NirmalaS.ttf
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-Bold.ttf
# Comic Sans MS C:\Windows\Fonts\comicbd.ttf
# HYSinMyeongJo-Medium C:\Windows\Fonts\H2MJSM.TTF
# Leelawadee UI C:\Windows\Fonts\LeelUIsl.ttf
# Algerian C:\Windows\Fonts\ALGER.TTF
# Bodoni MT C:\Windows\Fonts\BOD_PSTC.TTF
# Candara C:\Windows\Fonts\Candara.ttf
# Century Schoolbook C:\Windows\Fonts\CENSCBK.TTF
# Cascadia Mono C:\Windows\Fonts\CascadiaMono.ttf
# Snap ITC C:\Windows\Fonts\SNAP____.TTF
# Bodoni MT C:\Windows\Fonts\BOD_R.TTF
# Parchment C:\Windows\Fonts\PARCHM.TTF
# Gill Sans Ultra Bold Condensed C:\Windows\Fonts\GILLUBCD.TTF
# Brush Script MT C:\Windows\Fonts\BRUSHSCI.TTF
# Microsoft New Tai Lue C:\Windows\Fonts\ntailu.ttf
# Segoe Script C:\Windows\Fonts\segoescb.ttf
# Haan Wing2 C:\Windows\Fonts\HANWing2.ttf
# Webdings C:\Windows\Fonts\webdings.ttf
# Segoe Print C:\Windows\Fonts\segoepr.ttf
# Calibri C:\Windows\Fonts\calibrib.ttf
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Agency FB C:\Windows\Fonts\AGENCYR.TTF
# Wingdings C:\Windows\Fonts\wingding.ttf
# Rockwell Extra Bold C:\Windows\Fonts\ROCKEB.TTF
# Perpetua C:\Windows\Fonts\PERB____.TTF
# Kristen ITC C:\Windows\Fonts\ITCKRIST.TTF
# Lucida Handwriting C:\Windows\Fonts\LHANDW.TTF
# Bell MT C:\Windows\Fonts\BELLI.TTF
# Franklin Gothic Heavy C:\Windows\Fonts\FRAHV.TTF
# Calibri C:\Windows\Fonts\calibril.ttf
# Calibri C:\Windows\Fonts\calibri.ttf
# Corbel C:\Windows\Fonts\corbelz.ttf
# Segoe UI Emoji C:\Windows\Fonts\seguiemj.ttf
# Microsoft YaHei C:\Windows\Fonts\msyhl.ttc
# Yet R C:\Windows\Fonts\HMFMOLD.TTF
# Playbill C:\Windows\Fonts\PLAYBILL.TTF
# Leelawadee C:\Windows\Fonts\LEELAWDB.TTF
# Tahoma C:\Windows\Fonts\tahomabd.ttf
# Viner Hand ITC C:\Windows\Fonts\VINERITC.TTF
# Gill Sans MT C:\Windows\Fonts\GILI____.TTF
# Rockwell C:\Windows\Fonts\ROCKBI.TTF
# Lucida Sans Typewriter C:\Windows\Fonts\LTYPEBO.TTF
# Verdana C:\Windows\Fonts\verdanab.ttf
# Perpetua Titling MT C:\Windows\Fonts\PERTIBD.TTF
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Bodoni MT C:\Windows\Fonts\BOD_CI.TTF
# Franklin Gothic Heavy C:\Windows\Fonts\FRAHVIT.TTF
# Bodoni MT C:\Windows\Fonts\BOD_BLAR.TTF
# Tw Cen MT Condensed C:\Windows\Fonts\TCCB____.TTF
# Dubai C:\Windows\Fonts\DUBAI-MEDIUM.TTF
# LG PC C:\Windows\Fonts\LG PC.ttf
# Comic Sans MS C:\Windows\Fonts\comic.ttf
# HYGraphic-Medium C:\Windows\Fonts\H2GPRM.TTF
# Onyx C:\Windows\Fonts\ONYX.TTF
# Haettenschweiler C:\Windows\Fonts\HATTEN.TTF
# Segoe UI C:\Windows\Fonts\seguibli.ttf
# Palace Script MT C:\Windows\Fonts\PALSCRI.TTF
# Impact C:\Windows\Fonts\impact.ttf
# Dubai C:\Windows\Fonts\DUBAI-REGULAR.TTF
# Perpetua C:\Windows\Fonts\PERI____.TTF
# Sitka C:\Windows\Fonts\SitkaVF.ttf
# Gabriola C:\Windows\Fonts\Gabriola.ttf
# Rockwell Condensed C:\Windows\Fonts\ROCCB___.TTF
# Times New Roman C:\Windows\Fonts\times.ttf
# HCR Batang C:\Windows\Fonts\HANBatangB.ttf
# Calisto MT C:\Windows\Fonts\CALIST.TTF
# Batang C:\Windows\Fonts\batang.ttc
# MV Boli C:\Windows\Fonts\mvboli.ttf
# Book Antiqua C:\Windows\Fonts\ANTQUAI.TTF
# Segoe UI C:\Windows\Fonts\seguisli.ttf
# Magneto C:\Windows\Fonts\MAGNETOB.TTF
# Castellar C:\Windows\Fonts\CASTELAR.TTF
# Segoe MDL2 Assets C:\Windows\Fonts\segmdl2.ttf
# LG Smart UI C:\Windows\Fonts\LG_Smart_UI-SemiBold.ttf
# Tahoma C:\Windows\Fonts\tahoma.ttf
# Calisto MT C:\Windows\Fonts\CALISTBI.TTF
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# HYGothic-Extra C:\Windows\Fonts\H2GTRE.TTF
# Calibri C:\Windows\Fonts\calibrili.ttf
# Yu Gothic C:\Windows\Fonts\YuGothB.ttc
# Lucida Bright C:\Windows\Fonts\LBRITED.TTF
# Microsoft Uighur C:\Windows\Fonts\MSUIGHUB.TTF
# Broadway C:\Windows\Fonts\BROADW.TTF
# Gigi C:\Windows\Fonts\GIGI.TTF
# Malgun Gothic C:\Windows\Fonts\malgunsl.ttf
# Tw Cen MT Condensed Extra Bold C:\Windows\Fonts\TCCEB.TTF
# Juice ITC C:\Windows\Fonts\JUICE___.TTF
# Bodoni MT C:\Windows\Fonts\BOD_BLAI.TTF
# Bradley Hand ITC C:\Windows\Fonts\BRADHITC.TTF
# Bookshelf Symbol 7 C:\Windows\Fonts\BSSYM7.TTF
# Arial C:\Windows\Fonts\ariali.ttf
# Courier New C:\Windows\Fonts\cour.ttf
# Garamond C:\Windows\Fonts\GARAIT.TTF
# Vivaldi C:\Windows\Fonts\VIVALDII.TTF
# Georgia C:\Windows\Fonts\georgiaz.ttf
# Tw Cen MT C:\Windows\Fonts\TCM_____.TTF
# Corbel C:\Windows\Fonts\corbell.ttf
# HYHeadLine-Medium C:\Windows\Fonts\H2HDRM.TTF
# Consolas C:\Windows\Fonts\consolab.ttf
# Lucida Sans Unicode C:\Windows\Fonts\l_10646.ttf
# Segoe Print C:\Windows\Fonts\segoeprb.ttf
# Hancom MalangMalang C:\Windows\Fonts\MalangmalangR.ttf
# NewJumja C:\Windows\Fonts\JUMJA.TTF
# HCR Batang Ext C:\Windows\Fonts\HANBatangExt.ttf
# Arial C:\Windows\Fonts\ARIALNB.TTF
# Lucida Console C:\Windows\Fonts\lucon.ttf
# Hancom Hoonminjeongeum_H C:\Windows\Fonts\HancomHoonminjeongeumH.ttf
# Arial C:\Windows\Fonts\ARIALN.TTF
# Calibri C:\Windows\Fonts\calibriz.ttf
# Goudy Old Style C:\Windows\Fonts\GOUDOSI.TTF
# Segoe UI C:\Windows\Fonts\seguili.ttf
# Elephant C:\Windows\Fonts\ELEPHNTI.TTF
# Wide Latin C:\Windows\Fonts\LATINWD.TTF
# HCR Batang ExtB C:\Windows\Fonts\HANBatangExtB.ttf
# Showcard Gothic C:\Windows\Fonts\SHOWG.TTF
# Ebrima C:\Windows\Fonts\ebrima.ttf
# Candara C:\Windows\Fonts\Candarali.ttf
# Bookman Old Style C:\Windows\Fonts\BOOKOSBI.TTF

# %%
import pandas as pd
import numpy as np

# !pip install pykrx
from pykrx import stock

from tqdm import tqdm
import time

import seaborn as sns

# %%
df = pd.read_csv("./meta_data.csv")
df
# Out:
#        종목코드       종목명   시장구분   업종명      종가     대비   등락률             시가총액
# 0    120110     코오롱인더  KOSPI    화학   36550    -50 -0.14    1005822776050
# 1       150        두산  KOSPI  기타금융  137000   4100  3.09    2263765395000
# 2     24720     콜마홀딩스  KOSPI  기타금융    8250     20  0.24     303348540000
# 3     24720     콜마홀딩스  KOSPI  기타금융    8250     20  0.24     303348540000
# 4      4560   현대비앤지스틸  KOSPI  철강금속   20950    600  2.95     315901090450
# ..      ...       ...    ...   ...     ...    ...   ...              ...
# 141    4990      롯데지주  KOSPI  기타금융   26500   -300 -1.12    2780094780500
# 142  267260  HD현대일렉트릭  KOSPI  전기전자  255000  15000  6.25    9192019425000
# 143    1740    SK네트웍스  KOSPI   유통업    5540    -20 -0.36    1225879577080
# 144    5930      삼성전자  KOSPI  전기전자   78600   3100  4.11  469224908430000
# 145    9440   KC그린홀딩스  KOSPI  기타금융    2405      5  0.21      53956126900
#
# [146 rows x 8 columns]

# %%
df['종목코드'] = df['종목코드'].astype(str).str.zfill(6)

# %%
import numpy as np 
from statsmodels import regression
import statsmodels.api as sm 
import matplotlib.pyplot as plt 
import math
import pandas as pd 
import pandas_datareader as pdr

# %%
sector_counts = df.groupby('업종명').size().reset_index(name='종목수')

print(sector_counts)
# Out:
#       업종명  종목수
# 0     건설업    6
# 1      기계    3
# 2    기타금융   20
# 3      보험    4
# 4   비금속광물    4
# 5    서비스업   11
# 6    섬유의복    1
# 7    운수장비   10
# 8   운수창고업    6
# 9     유통업   13
# 10     은행    2
# 11   음식료품    3
# 12    의약품    7
# 13  전기가스업    3
# 14   전기전자   13
# 15   종이목재    2
# 16     증권    5
# 17   철강금속    7
# 18    통신업    2
# 19     화학   24

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import networkx as nx
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

import seaborn as sns
import networkx as nx

# %%
def create_graph_with_correlation(df, start, end):
    G = nx.Graph()
    
    # 모든 주식의 종가 데이터 가져오기
    stock_prices = {}
    for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
        code = row["종목코드"]
        name = row["종목명"]
        sector = row["업종명"]
        try:
            asset = fdr.DataReader(code, start, end)
            stock_prices[code] = asset['Close']
        except:
            print(f"No data for {code} ({name})")
            continue
    
    # 가장 긴 공통 기간 찾기
    min_date = max([prices.index.min() for prices in stock_prices.values() if not prices.empty])
    max_date = min([prices.index.max() for prices in stock_prices.values() if not prices.empty])
    
    # 유효한 기간이 없는 경우 처리
    if pd.isna(min_date) or pd.isna(max_date):
        raise ValueError("No common dates available in the dataset.")
    
    # 공통 기간 내의 데이터를 기준으로 필터링
    common_dates = pd.date_range(start=min_date, end=max_date)
    print(f"Common date range: {min_date} to {max_date}")

    filtered_prices = {}
    for code in stock_prices:
        filtered_prices[code] = stock_prices[code].reindex(common_dates).dropna()
    
    # 시가총액 상위 50개 종목 선택
    valid_codes = [code for code in filtered_prices if len(filtered_prices[code]) > 0]
    top_50_df = df[df['종목코드'].isin(valid_codes)].nlargest(50, '시가총액')

    print(f"Valid codes after filtering: {len(valid_codes)}")
    print(f"Top 50 codes selected: {len(top_50_df)}")

    # 시가총액 상위 50개 종목에 대해 다시 종가 데이터를 가져오기
    stock_prices_top_50 = {code: filtered_prices[code] for code in top_50_df['종목코드']}

    for idx, row in tqdm(top_50_df.iterrows(), total=top_50_df.shape[0]):
        code = row["종목코드"]
        name = row["종목명"]
        sector = row["업종명"]
        
        # 그래프 노드에 종목명과 업종명 추가
        G.add_node(name, sector=sector)
    
    codes = list(stock_prices_top_50.keys())
    edge_count = 0
    for i in range(len(codes)):
        for j in range(i + 1, len(codes)):
            code_i = codes[i]
            code_j = codes[j]
            
            # 두 종목의 종가 데이터 가져오기
            prices_i = stock_prices_top_50[code_i]
            prices_j = stock_prices_top_50[code_j]
            
            # 상관 관계 계산
            if len(prices_i) > 1 and len(prices_j) > 1:  # 최소한 두 개의 데이터 포인트가 있는 경우
                correlation = prices_i.corr(prices_j)
                if not np.isnan(correlation) and correlation > 0.5:  # 상관 관계가 높은 경우만 엣지 추가
                    G.add_edge(df.loc[df['종목코드'] == code_i, '종목명'].values[0], 
                               df.loc[df['종목코드'] == code_j, '종목명'].values[0], 
                               weight=correlation)
                    edge_count += 1
    
    print(f"Total edges added: {edge_count}")

    # 연결된 엣지가 없는 노드 제거
    nodes_to_remove = [node for node in G.nodes if G.degree(node) == 0]
    G.remove_nodes_from(nodes_to_remove)
    print(f"Nodes removed due to no edges: {len(nodes_to_remove)}")

    return G

# %%
start_date = '2020-03-01'
end_date = '2020-04-30'

G = create_graph_with_correlation(df, start_date, end_date)

num_nodes = G.number_of_nodes()

print(f"Number of nodes in the graph: {num_nodes}")
# Out:
# 100%|██████████| 146/146 [01:07<00:00,  2.18it/s]
# Common date range: 2020-03-02 00:00:00 to 2020-04-29 00:00:00
# Valid codes after filtering: 129
# Top 50 codes selected: 50
# 100%|██████████| 50/50 [00:00<00:00, 5673.04it/s]
# Total edges added: 864
# Nodes removed due to no edges: 1
# Number of nodes in the graph: 44

# %%
print("Edge weights:")
for (u, v, weight) in G.edges(data=True):
    print(f"({u}, {v}): {weight['weight']}")
# Out:
# Edge weights:
# (삼성전자, 기아): 0.9429018858976089
# (삼성전자, NAVER): 0.534152018993626
# (삼성전자, LG화학): 0.9137149359152471
# (삼성전자, 포스코퓨처엠): 0.924924347246087
# (삼성전자, 현대모비스): 0.937050098199132
# (삼성전자, 신한지주): 0.9108484619459951
# (삼성전자, 카카오): 0.7086175427838706
# (삼성전자, 삼성생명): 0.9156567822434408
# (삼성전자, 하나금융지주): 0.9286319970874687
# (삼성전자, LG전자): 0.9423195146005372
# (삼성전자, LG): 0.9298881837936963
# (삼성전자, 한화에어로스페이스): 0.885874376602731
# (삼성전자, SK): 0.8093155175496808
# (삼성전자, 삼성에스디에스): 0.9278778653544648
# (삼성전자, 삼성전기): 0.9724176759849164
# (삼성전자, SK텔레콤): 0.8208619374923847
# (삼성전자, 기업은행): 0.9519503490033928
# (삼성전자, SK이노베이션): 0.8700613657758874
# (삼성전자, 우리금융지주): 0.948656201363895
# (삼성전자, 두산에너빌리티): 0.8782330150658424
# (삼성전자, 고려아연): 0.8132233194986198
# (삼성전자, HD현대일렉트릭): 0.8946571092971699
# (삼성전자, HD한국조선해양): 0.9311741948472712
# (삼성전자, S-Oil): 0.5049725626952198
# (삼성전자, 삼성중공업): 0.9497588604770069
# (삼성전자, 포스코인터내셔널): 0.8490687889833182
# (삼성전자, 대한항공): 0.9205714560690814
# (삼성전자, 한국타이어앤테크놀로지): 0.9335128338680325
# (삼성전자, 현대글로비스): 0.9515771122496378
# (삼성전자, LG생활건강): 0.5025680668385016
# (삼성전자, 한국항공우주): 0.8393498426598753
# (삼성전자, LG디스플레이): 0.9577881971979709
# (삼성전자, LG이노텍): 0.7662490522185929
# (삼성전자, SKC): 0.8384545257370895
# (삼성전자, LG유플러스): 0.8040678727651763
# (삼성전자, 한화솔루션): 0.9618524463219015
# (삼성전자, 한미약품): 0.8617067518142633
# (삼성전자, NH투자증권): 0.9290420678962609
# (삼성바이오로직스, NAVER): 0.8321208124618003
# (삼성바이오로직스, LG화학): 0.59737768815775
# (삼성바이오로직스, 포스코퓨처엠): 0.5743917079764994
# (삼성바이오로직스, 카카오): 0.8194657995952925
# (삼성바이오로직스, 삼성생명): 0.5535052276376867
# (삼성바이오로직스, 한화에어로스페이스): 0.5791620926870047
# (삼성바이오로직스, SK): 0.6903864110969117
# (삼성바이오로직스, 삼성에스디에스): 0.5276095527430417
# (삼성바이오로직스, SK텔레콤): 0.5986433605940521
# (삼성바이오로직스, SK이노베이션): 0.5791519108535854
# (삼성바이오로직스, 고려아연): 0.6506834796745001
# (삼성바이오로직스, HD현대일렉트릭): 0.5621743902972256
# (삼성바이오로직스, S-Oil): 0.7594518731270145
# (삼성바이오로직스, 포스코인터내셔널): 0.5893494276395471
# (삼성바이오로직스, LG생활건강): 0.8348354613052366
# (삼성바이오로직스, 유한양행): 0.734387580084737
# (삼성바이오로직스, 한국항공우주): 0.6908309768883464
# (삼성바이오로직스, LG이노텍): 0.7397886592496807
# (삼성바이오로직스, 현대로템): 0.891613798985436
# (삼성바이오로직스, SKC): 0.6947038423113551
# (삼성바이오로직스, 롯데케미칼): 0.8898765746705818
# (삼성바이오로직스, LG유플러스): 0.6722479606233402
# (삼성바이오로직스, 한진칼): 0.7650767551432236
# (기아, NAVER): 0.5489514374290515
# (기아, LG화학): 0.8996783959104658
# (기아, 포스코퓨처엠): 0.925764259693521
# (기아, 현대모비스): 0.9364623287980783
# (기아, 신한지주): 0.914364680127416
# (기아, 카카오): 0.6991045300153866
# (기아, 삼성생명): 0.936211405034538
# (기아, 하나금융지주): 0.9485183760845793
# (기아, LG전자): 0.9748338436556562
# (기아, LG): 0.9129379816346577
# (기아, 한화에어로스페이스): 0.9208438414959563
# (기아, SK): 0.8365533513759156
# (기아, 삼성에스디에스): 0.9206307354430512
# (기아, 삼성전기): 0.922194463892985
# (기아, SK텔레콤): 0.85228881184997
# (기아, 기업은행): 0.9472424289980668
# (기아, SK이노베이션): 0.894222807631973
# (기아, 우리금융지주): 0.9535893175742137
# (기아, 두산에너빌리티): 0.8977445572830276
# (기아, 고려아연): 0.8353544936138512
# (기아, HD현대일렉트릭): 0.906988671230122
# (기아, HD한국조선해양): 0.908206469554676
# (기아, S-Oil): 0.6148285977752576
# (기아, 삼성중공업): 0.949724835988204
# (기아, 포스코인터내셔널): 0.9242288169505466
# (기아, 대한항공): 0.9177849971839925
# (기아, 한국타이어앤테크놀로지): 0.9808803691037095
# (기아, 현대글로비스): 0.9877284700575731
# (기아, LG생활건강): 0.538075835031415
# (기아, 유한양행): 0.6173559761760207
# (기아, 한국항공우주): 0.8588438079132859
# (기아, LG디스플레이): 0.9176673749170448
# (기아, LG이노텍): 0.7746302943659411
# (기아, SKC): 0.8569216589432356
# (기아, LG유플러스): 0.857016852590245
# (기아, 한화솔루션): 0.9514239575429192
# (기아, 한미약품): 0.8815402977283464
# (기아, NH투자증권): 0.9218236303425243
# (NAVER, LG화학): 0.7320407180836619
# (NAVER, 포스코퓨처엠): 0.7235756239562647
# (NAVER, 현대모비스): 0.5541383416646197
# (NAVER, 신한지주): 0.6511779858996188
# (NAVER, 카카오): 0.9347761066749466
# (NAVER, 삼성생명): 0.6536294540456767
# (NAVER, 하나금융지주): 0.6357695632730944
# (NAVER, LG전자): 0.5896859347664721
# (NAVER, LG): 0.6781139089518543
# (NAVER, 한화에어로스페이스): 0.7740722149730377
# (NAVER, SK): 0.8022269607830138
# (NAVER, 삼성에스디에스): 0.6572102051140356
# (NAVER, 삼성전기): 0.532601013420996
# (NAVER, SK텔레콤): 0.7407995295007551
# (NAVER, 기업은행): 0.5141452064373384
# (NAVER, SK이노베이션): 0.7232759598776599
# (NAVER, 우리금융지주): 0.6206892129963839
# (NAVER, 두산에너빌리티): 0.6330733253555586
# (NAVER, 고려아연): 0.7378621820127467
# (NAVER, HD현대일렉트릭): 0.7552419331274641
# (NAVER, S-Oil): 0.8163927651426677
# (NAVER, 포스코인터내셔널): 0.7542733706179159
# (NAVER, 대한항공): 0.5063577772634403
# (NAVER, 한국타이어앤테크놀로지): 0.535785983938608
# (NAVER, 현대글로비스): 0.5304592425798564
# (NAVER, LG생활건강): 0.8928639086489423
# (NAVER, 유한양행): 0.7497299533034582
# (NAVER, 한국항공우주): 0.8403979009508576
# (NAVER, LG이노텍): 0.8373979759134891
# (NAVER, 현대로템): 0.9086659155814398
# (NAVER, SKC): 0.7862130421500653
# (NAVER, 롯데케미칼): 0.9237796395704054
# (NAVER, LG유플러스): 0.8275980968871208
# (NAVER, 한화솔루션): 0.58410367405903
# (NAVER, 한미약품): 0.6316180651691334
# (NAVER, 한진칼): 0.7590769922132088
# (NAVER, NH투자증권): 0.6406334364928209
# (LG화학, 포스코퓨처엠): 0.9831091543136685
# (LG화학, 현대모비스): 0.8715846603444575
# (LG화학, 신한지주): 0.873028626754753
# (LG화학, 카카오): 0.882637576552383
# (LG화학, 삼성생명): 0.9345986871441969
# (LG화학, 하나금융지주): 0.8930874236346525
# (LG화학, LG전자): 0.9064218509488794
# (LG화학, LG): 0.9211984537535968
# (LG화학, 한화에어로스페이스): 0.9519225381517026
# (LG화학, SK): 0.8691266229539303
# (LG화학, 삼성에스디에스): 0.9332744659434653
# (LG화학, 삼성전기): 0.9303937257305782
# (LG화학, SK텔레콤): 0.9166378308226185
# (LG화학, 기업은행): 0.8612669509792752
# (LG화학, SK이노베이션): 0.8753464776108371
# (LG화학, 우리금융지주): 0.9186340814200746
# (LG화학, 두산에너빌리티): 0.8352400328821201
# (LG화학, 고려아연): 0.8656146752133802
# (LG화학, HD현대일렉트릭): 0.9536925118462659
# (LG화학, HD한국조선해양): 0.7761935409397729
# (LG화학, S-Oil): 0.6364045080432729
# (LG화학, 삼성중공업): 0.8308738338557483
# (LG화학, 포스코인터내셔널): 0.8778540377682664
# (LG화학, 대한항공): 0.8700884459625879
# (LG화학, 한국타이어앤테크놀로지): 0.8794421602710846
# (LG화학, 현대글로비스): 0.8923279541157663
# (LG화학, LG생활건강): 0.7086686278463987
# (LG화학, 유한양행): 0.6264572943351705
# (LG화학, 한국항공우주): 0.9371062255489838
# (LG화학, LG디스플레이): 0.821956092926439
# (LG화학, LG이노텍): 0.8434649717376621
# (LG화학, 현대로템): 0.6758330673140153
# (LG화학, SKC): 0.9639711525597026
# (LG화학, 롯데케미칼): 0.6710827910704594
# (LG화학, LG유플러스): 0.9053118508482766
# (LG화학, 한화솔루션): 0.9093694023882656
# (LG화학, 한미약품): 0.8368554737033794
# (LG화학, 한진칼): 0.5306581947304487
# (LG화학, NH투자증권): 0.8863008944844716
# (포스코퓨처엠, 현대모비스): 0.9004181596347671
# (포스코퓨처엠, 신한지주): 0.8748093426544024
# (포스코퓨처엠, 카카오): 0.872668567125066
# (포스코퓨처엠, 삼성생명): 0.9351450921355074
# (포스코퓨처엠, 하나금융지주): 0.9009811745115157
# (포스코퓨처엠, LG전자): 0.9364911058052734
# (포스코퓨처엠, LG): 0.9371310637180555
# (포스코퓨처엠, 한화에어로스페이스): 0.9590291840692149
# (포스코퓨처엠, SK): 0.8882246138013291
# (포스코퓨처엠, 삼성에스디에스): 0.9511102615782635
# (포스코퓨처엠, 삼성전기): 0.9379918349419354
# (포스코퓨처엠, SK텔레콤): 0.9381288785588676
# (포스코퓨처엠, 기업은행): 0.8782343956047616
# (포스코퓨처엠, SK이노베이션): 0.8995248990910398
# (포스코퓨처엠, 우리금융지주): 0.9251001942635537
# (포스코퓨처엠, 두산에너빌리티): 0.8705496819671152
# (포스코퓨처엠, 고려아연): 0.8874843848598534
# (포스코퓨처엠, HD현대일렉트릭): 0.9746164794930192
# (포스코퓨처엠, HD한국조선해양): 0.8017950041148589
# (포스코퓨처엠, S-Oil): 0.6657212286706424
# (포스코퓨처엠, 삼성중공업): 0.8707022482485451
# (포스코퓨처엠, 포스코인터내셔널): 0.9071004494215115
# (포스코퓨처엠, 대한항공): 0.8918532081566666
# (포스코퓨처엠, 한국타이어앤테크놀로지): 0.91676486051346
# (포스코퓨처엠, 현대글로비스): 0.9243452432967622
# (포스코퓨처엠, LG생활건강): 0.7049372189921924
# (포스코퓨처엠, 유한양행): 0.6537433630439173
# (포스코퓨처엠, 한국항공우주): 0.9364934153825676
# (포스코퓨처엠, LG디스플레이): 0.844492956700249
# (포스코퓨처엠, LG이노텍): 0.8528595773321759
# (포스코퓨처엠, 현대로템): 0.6642883901196699
# (포스코퓨처엠, SKC): 0.9683487591835522
# (포스코퓨처엠, 롯데케미칼): 0.6534881136884388
# (포스코퓨처엠, LG유플러스): 0.927520808160281
# (포스코퓨처엠, 한화솔루션): 0.931556211217697
# (포스코퓨처엠, 한미약품): 0.8757369083804168
# (포스코퓨처엠, 한진칼): 0.5440529677302092
# (포스코퓨처엠, NH투자증권): 0.9027731123234712
# (현대모비스, 신한지주): 0.9388625764648019
# (현대모비스, 카카오): 0.6867032945341471
# (현대모비스, 삼성생명): 0.9400685390392441
# (현대모비스, 하나금융지주): 0.907692066517777
# (현대모비스, LG전자): 0.9336056827012292
# (현대모비스, LG): 0.9458468952832609
# (현대모비스, 한화에어로스페이스): 0.8641515990495614
# (현대모비스, SK): 0.9011071163058697
# (현대모비스, 삼성에스디에스): 0.8825220486591723
# (현대모비스, 삼성전기): 0.8829506230051446
# (현대모비스, SK텔레콤): 0.7539059687676815
# (현대모비스, 기업은행): 0.9652451170593501
# (현대모비스, SK이노베이션): 0.9493159919364593
# (현대모비스, 우리금융지주): 0.9172338492475561
# (현대모비스, 두산에너빌리티): 0.9166409361035008
# (현대모비스, 고려아연): 0.8829640965470666
# (현대모비스, HD현대일렉트릭): 0.8561926811970796
# (현대모비스, HD한국조선해양): 0.8940830144774952
# (현대모비스, S-Oil): 0.5947102772727652
# (현대모비스, 삼성중공업): 0.9148430433595708
# (현대모비스, 포스코인터내셔널): 0.8777871550527603
# (현대모비스, 대한항공): 0.9118857312680279
# (현대모비스, 한국타이어앤테크놀로지): 0.9231396053218236
# (현대모비스, 현대글로비스): 0.9380556997509701
# (현대모비스, 유한양행): 0.6301364237663961
# (현대모비스, 한국항공우주): 0.847415358827663
# (현대모비스, LG디스플레이): 0.9301512643686108
# (현대모비스, LG이노텍): 0.8194448512635474
# (현대모비스, SKC): 0.829108542513803
# (현대모비스, 롯데케미칼): 0.5279063991700378
# (현대모비스, LG유플러스): 0.7962176401022462
# (현대모비스, 한화솔루션): 0.9586007399034305
# (현대모비스, 한미약품): 0.9095143771327551
# (현대모비스, NH투자증권): 0.941750738413731
# (신한지주, 카카오): 0.7292929249211283
# (신한지주, 삼성생명): 0.9346612716907117
# (신한지주, 하나금융지주): 0.9661164662606696
# (신한지주, LG전자): 0.9223411698993179
# (신한지주, LG): 0.9336288093231282
# (신한지주, 한화에어로스페이스): 0.9066121890420339
# (신한지주, SK): 0.8914409077532569
# (신한지주, 삼성에스디에스): 0.8527417330344539
# (신한지주, 삼성전기): 0.8567103978440737
# (신한지주, SK텔레콤): 0.7637726150900087
# (신한지주, 기업은행): 0.9553952683630981
# (신한지주, SK이노베이션): 0.9282653958919931
# (신한지주, 우리금융지주): 0.9418492217501756
# (신한지주, 두산에너빌리티): 0.8837003001072116
# (신한지주, 고려아연): 0.8550136243905746
# (신한지주, HD현대일렉트릭): 0.8542834618307165
# (신한지주, HD한국조선해양): 0.8475429318815997
# (신한지주, S-Oil): 0.6231288762106922
# (신한지주, 삼성중공업): 0.8653023953622198
# (신한지주, 포스코인터내셔널): 0.8954432861225221
# (신한지주, 대한항공): 0.887000055575952
# (신한지주, 한국타이어앤테크놀로지): 0.8895759371413383
# (신한지주, 현대글로비스): 0.9011697003705965
# (신한지주, LG생활건강): 0.5170387523241499
# (신한지주, 유한양행): 0.6425640607138682
# (신한지주, 한국항공우주): 0.8903387739303085
# (신한지주, LG디스플레이): 0.8882264195553848
# (신한지주, LG이노텍): 0.8395172779891497
# (신한지주, SKC): 0.8120518327824361
# (신한지주, 롯데케미칼): 0.6170675112721756
# (신한지주, LG유플러스): 0.8256976476224184
# (신한지주, 한화솔루션): 0.9445766570186551
# (신한지주, 한미약품): 0.890979895807182
# (신한지주, 한진칼): 0.5028084501569696
# (신한지주, NH투자증권): 0.9596471348078677
# (카카오, 삼성생명): 0.7952642980422064
# (카카오, 하나금융지주): 0.7391081815572328
# (카카오, LG전자): 0.7253873220358324
# (카카오, LG): 0.7876367559591002
# (카카오, 한화에어로스페이스): 0.8684546883588706
# (카카오, SK): 0.8414933074249029
# (카카오, 삼성에스디에스): 0.8214312775560902
# (카카오, 삼성전기): 0.736226821208299
# (카카오, SK텔레콤): 0.8590502490126739
# (카카오, 기업은행): 0.6596862247663413
# (카카오, SK이노베이션): 0.8038316528430043
# (카카오, 우리금융지주): 0.7641479222794991
# (카카오, 두산에너빌리티): 0.7343207120831667
# (카카오, 고려아연): 0.801436490776325
# (카카오, HD현대일렉트릭): 0.8873063134076169
# (카카오, HD한국조선해양): 0.5085957686407846
# (카카오, S-Oil): 0.7789526979021931
# (카카오, 삼성중공업): 0.5797077421576272
# (카카오, 포스코인터내셔널): 0.8173198570193667
# (카카오, 대한항공): 0.6270750011437122
# (카카오, 한국타이어앤테크놀로지): 0.673054087239831
# (카카오, 현대글로비스): 0.6850734964473357
# (카카오, LG생활건강): 0.9077233489398847
# (카카오, 유한양행): 0.6900050616750125
# (카카오, 한국항공우주): 0.9160065615996094
# (카카오, LG디스플레이): 0.5606802791278999
# (카카오, LG이노텍): 0.8916599958211681
# (카카오, 현대로템): 0.8971639779132254
# (카카오, SKC): 0.9145420285567503
# (카카오, 롯데케미칼): 0.8612780233302517
# (카카오, LG유플러스): 0.8865640627170256
# (카카오, 한화솔루션): 0.7219381856886962
# (카카오, 한미약품): 0.7083008453418548
# (카카오, 한진칼): 0.6737309304786255
# (카카오, NH투자증권): 0.7166784342419127
# (삼성생명, 하나금융지주): 0.9270497252299901
# (삼성생명, LG전자): 0.9191515647733747
# (삼성생명, LG): 0.9299082608194981
# (삼성생명, 한화에어로스페이스): 0.9173523317623414
# (삼성생명, SK): 0.8984163618168595
# (삼성생명, 삼성에스디에스): 0.8985560998124854
# (삼성생명, 삼성전기): 0.8876490850961516
# (삼성생명, SK텔레콤): 0.8249556849481223
# (삼성생명, 기업은행): 0.9362116836197305
# (삼성생명, SK이노베이션): 0.9359589628207409
# (삼성생명, 우리금융지주): 0.9423923323554748
# (삼성생명, 두산에너빌리티): 0.8902967058932751
# (삼성생명, 고려아연): 0.8898842021262607
# (삼성생명, HD현대일렉트릭): 0.894655822514369
# (삼성생명, HD한국조선해양): 0.8302944632884152
# (삼성생명, S-Oil): 0.6423197574422742
# (삼성생명, 삼성중공업): 0.8684369809133712
# (삼성생명, 포스코인터내셔널): 0.8958990924212622
# (삼성생명, 대한항공): 0.8686416242388553
# (삼성생명, 한국타이어앤테크놀로지): 0.9110910278886466
# (삼성생명, 현대글로비스): 0.9226182804333873
# (삼성생명, LG생활건강): 0.5915020498802344
# (삼성생명, 유한양행): 0.6417369834062566
# (삼성생명, 한국항공우주): 0.9059526981324084
# (삼성생명, LG디스플레이): 0.8615443095570655
# (삼성생명, LG이노텍): 0.8526192936355231
# (삼성생명, 현대로템): 0.5592797964501554
# (삼성생명, SKC): 0.8942457062047486
# (삼성생명, 롯데케미칼): 0.629425668889775
# (삼성생명, LG유플러스): 0.8557823466618185
# (삼성생명, 한화솔루션): 0.9327839162347527
# (삼성생명, 한미약품): 0.8543660965481313
# (삼성생명, 한진칼): 0.5327551793961173
# (삼성생명, NH투자증권): 0.8982466881727426
# (하나금융지주, LG전자): 0.9449552281501085
# (하나금융지주, LG): 0.9089072203292019
# (하나금융지주, 한화에어로스페이스): 0.9336557738686049
# (하나금융지주, SK): 0.8396118645150424
# (하나금융지주, 삼성에스디에스): 0.8800678399629039
# (하나금융지주, 삼성전기): 0.9092013517985995
# (하나금융지주, SK텔레콤): 0.8242988285198674
# (하나금융지주, 기업은행): 0.9550198385967968
# (하나금융지주, SK이노베이션): 0.8879768296421512
# (하나금융지주, 우리금융지주): 0.973427121001679
# (하나금융지주, 두산에너빌리티): 0.8987807805295477
# (하나금융지주, 고려아연): 0.8102740356343995
# (하나금융지주, HD현대일렉트릭): 0.9034273272354764
# (하나금융지주, HD한국조선해양): 0.8811957567834093
# (하나금융지주, S-Oil): 0.6010851951453918
# (하나금융지주, 삼성중공업): 0.9109278334889548
# (하나금융지주, 포스코인터내셔널): 0.9093838755114686
# (하나금융지주, 대한항공): 0.8942110326887542
# (하나금융지주, 한국타이어앤테크놀로지): 0.9312096446074639
# (하나금융지주, 현대글로비스): 0.9340984546981514
# (하나금융지주, LG생활건강): 0.5464299420551609
# (하나금융지주, 유한양행): 0.5973726841691902
# (하나금융지주, 한국항공우주): 0.8813109063012391
# (하나금융지주, LG디스플레이): 0.9054978488149648
# (하나금융지주, LG이노텍): 0.8006899555291299
# (하나금융지주, SKC): 0.833387639109306
# (하나금융지주, 롯데케미칼): 0.5466482759568704
# (하나금융지주, LG유플러스): 0.8569628720191784
# (하나금융지주, 한화솔루션): 0.9568813679824891
# (하나금융지주, 한미약품): 0.8572128440053669
# (하나금융지주, NH투자증권): 0.9440281141669236
# (LG전자, LG): 0.944178005780601
# (LG전자, 한화에어로스페이스): 0.9336540114519433
# (LG전자, SK): 0.8570334859016869
# (LG전자, 삼성에스디에스): 0.9127511673420757
# (LG전자, 삼성전기): 0.9244857883840073
# (LG전자, SK텔레콤): 0.8751179493781964
# (LG전자, 기업은행): 0.932156097924509
# (LG전자, SK이노베이션): 0.9109024219915534
# (LG전자, 우리금융지주): 0.9319605476316147
# (LG전자, 두산에너빌리티): 0.8889296751734442
# (LG전자, 고려아연): 0.8723324155006809
# (LG전자, HD현대일렉트릭): 0.910122346620101
# (LG전자, HD한국조선해양): 0.8836077292836795
# (LG전자, S-Oil): 0.6517598233942906
# (LG전자, 삼성중공업): 0.9400750176779559
# (LG전자, 포스코인터내셔널): 0.9378763485947598
# (LG전자, 대한항공): 0.9414057029612847
# (LG전자, 한국타이어앤테크놀로지): 0.9714115609473499
# (LG전자, 현대글로비스): 0.9782294703503783
# (LG전자, LG생활건강): 0.5694123858420821
# (LG전자, 유한양행): 0.6405537147002512
# (LG전자, 한국항공우주): 0.8840099152114678
# (LG전자, LG디스플레이): 0.9053326911685148
# (LG전자, LG이노텍): 0.7949295702110224
# (LG전자, SKC): 0.867493828288978
# (LG전자, 롯데케미칼): 0.5114632076567547
# (LG전자, LG유플러스): 0.8939315311206677
# (LG전자, 한화솔루션): 0.9541521762468511
# (LG전자, 한미약품): 0.9188254583199903
# (LG전자, NH투자증권): 0.9460629224126444
# (LG, 한화에어로스페이스): 0.925323381128318
# (LG, SK): 0.9167650033345078
# (LG, 삼성에스디에스): 0.911128174395999
# (LG, 삼성전기): 0.8877842544534857
# (LG, SK텔레콤): 0.851493229904988
# (LG, 기업은행): 0.9066863003032173
# (LG, SK이노베이션): 0.9447288067869912
# (LG, 우리금융지주): 0.9034984047907054
# (LG, 두산에너빌리티): 0.8753614193254219
# (LG, 고려아연): 0.9261488620348302
# (LG, HD현대일렉트릭): 0.8953758951818275
# (LG, HD한국조선해양): 0.8060278633375825
# (LG, S-Oil): 0.6696714369438664
# (LG, 삼성중공업): 0.8626298676358967
# (LG, 포스코인터내셔널): 0.9152414518123531
# (LG, 대한항공): 0.9045297993290867
# (LG, 한국타이어앤테크놀로지): 0.9104136624363374
# (LG, 현대글로비스): 0.9295612737471534
# (LG, LG생활건강): 0.6181562741370906
# (LG, 유한양행): 0.6772391936079905
# (LG, 한국항공우주): 0.9198195669189455
# (LG, LG디스플레이): 0.8634632412670392
# (LG, LG이노텍): 0.8628012825968605
# (LG, 현대로템): 0.5647353870386882
# (LG, SKC): 0.8928814288758432
# (LG, 롯데케미칼): 0.6382043178948595
# (LG, LG유플러스): 0.8903420439685474
# (LG, 한화솔루션): 0.9309285920440463
# (LG, 한미약품): 0.9251438934948163
# (LG, 한진칼): 0.5210935255194952
# (LG, NH투자증권): 0.9466061474043481
# (한화에어로스페이스, SK): 0.884287964669698
# (한화에어로스페이스, 삼성에스디에스): 0.908615625304815
# (한화에어로스페이스, 삼성전기): 0.8874488077347619
# (한화에어로스페이스, SK텔레콤): 0.9341579529914641
# (한화에어로스페이스, 기업은행): 0.859887556174006
# (한화에어로스페이스, SK이노베이션): 0.8972674194148123
# (한화에어로스페이스, 우리금융지주): 0.9200728245983117
# (한화에어로스페이스, 두산에너빌리티): 0.877066867574534
# (한화에어로스페이스, 고려아연): 0.8706232123133976
# (한화에어로스페이스, HD현대일렉트릭): 0.9637902109203711
# (한화에어로스페이스, HD한국조선해양): 0.764085006054867
# (한화에어로스페이스, S-Oil): 0.721582441911376
# (한화에어로스페이스, 삼성중공업): 0.8377832856868084
# (한화에어로스페이스, 포스코인터내셔널): 0.9453265451822883
# (한화에어로스페이스, 대한항공): 0.8763615419556124
# (한화에어로스페이스, 한국타이어앤테크놀로지): 0.9124346185512521
# (한화에어로스페이스, 현대글로비스): 0.9088544361825033
# (한화에어로스페이스, LG생활건강): 0.746519138720988
# (한화에어로스페이스, 유한양행): 0.7112991324574061
# (한화에어로스페이스, 한국항공우주): 0.9737903137432703
# (한화에어로스페이스, LG디스플레이): 0.8016096957716518
# (한화에어로스페이스, LG이노텍): 0.8542508310147982
# (한화에어로스페이스, 현대로템): 0.692047048571483
# (한화에어로스페이스, SKC): 0.9421449391893376
# (한화에어로스페이스, 롯데케미칼): 0.6963879230463873
# (한화에어로스페이스, LG유플러스): 0.9493414609610672
# (한화에어로스페이스, 한화솔루션): 0.9192165619179573
# (한화에어로스페이스, 한미약품): 0.870195993084909
# (한화에어로스페이스, 한진칼): 0.5884846456943386
# (한화에어로스페이스, NH투자증권): 0.914583289858336
# (SK, 삼성에스디에스): 0.8534265277474029
# (SK, 삼성전기): 0.7482520119261651
# (SK, SK텔레콤): 0.7839845884322989
# (SK, 기업은행): 0.8348954494447202
# (SK, SK이노베이션): 0.9644289313421832
# (SK, 우리금융지주): 0.8331900440265899
# (SK, 두산에너빌리티): 0.8923077103155719
# (SK, 고려아연): 0.9606941311023165
# (SK, HD현대일렉트릭): 0.8538540204500181
# (SK, HD한국조선해양): 0.6660431488720433
# (SK, S-Oil): 0.8017888071570077
# (SK, 삼성중공업): 0.723149524015846
# (SK, 포스코인터내셔널): 0.9183401590777156
# (SK, 대한항공): 0.8083674300458641
# (SK, 한국타이어앤테크놀로지): 0.821198781650279
# (SK, 현대글로비스): 0.826058126084239
# (SK, LG생활건강): 0.6803328572843546
# (SK, 유한양행): 0.8441661192053366
# (SK, 한국항공우주): 0.919564907473519
# (SK, LG디스플레이): 0.7358345863743452
# (SK, LG이노텍): 0.9374866954717611
# (SK, 현대로템): 0.7052538428283183
# (SK, SKC): 0.8910911131671799
# (SK, 롯데케미칼): 0.8029624591811705
# (SK, LG유플러스): 0.8800808346244983
# (SK, 한화솔루션): 0.8589523580240198
# (SK, 한미약품): 0.9148698614029092
# (SK, 한진칼): 0.7290759905389682
# (SK, NH투자증권): 0.8873645260529677
# (삼성에스디에스, 삼성전기): 0.9229874527273065
# (삼성에스디에스, SK텔레콤): 0.9003741638147398
# (삼성에스디에스, 기업은행): 0.8720388087496797
# (삼성에스디에스, SK이노베이션): 0.8669059676228503
# (삼성에스디에스, 우리금융지주): 0.9133918727760189
# (삼성에스디에스, 두산에너빌리티): 0.8742253847215853
# (삼성에스디에스, 고려아연): 0.8393332787785626
# (삼성에스디에스, HD현대일렉트릭): 0.9331085911245226
# (삼성에스디에스, HD한국조선해양): 0.8182126996985429
# (삼성에스디에스, S-Oil): 0.6374792805031855
# (삼성에스디에스, 삼성중공업): 0.8632419424263308
# (삼성에스디에스, 포스코인터내셔널): 0.8972539135705387
# (삼성에스디에스, 대한항공): 0.8280885152212726
# (삼성에스디에스, 한국타이어앤테크놀로지): 0.8969718617695335
# (삼성에스디에스, 현대글로비스): 0.9190838910734404
# (삼성에스디에스, LG생활건강): 0.6819028846350297
# (삼성에스디에스, 유한양행): 0.63128308753817
# (삼성에스디에스, 한국항공우주): 0.8916954648058147
# (삼성에스디에스, LG디스플레이): 0.851205059903144
# (삼성에스디에스, LG이노텍): 0.8485522234120246
# (삼성에스디에스, 현대로템): 0.609136073365595
# (삼성에스디에스, SKC): 0.9198347116326347
# (삼성에스디에스, 롯데케미칼): 0.5603239629555357
# (삼성에스디에스, LG유플러스): 0.8729381045438728
# (삼성에스디에스, 한화솔루션): 0.9024491243131576
# (삼성에스디에스, 한미약품): 0.8782827956366912
# (삼성에스디에스, 한진칼): 0.5175991055815439
# (삼성에스디에스, NH투자증권): 0.8731142949649714
# (삼성전기, SK텔레콤): 0.85622644451928
# (삼성전기, 기업은행): 0.9136887688071003
# (삼성전기, SK이노베이션): 0.8129211346303364
# (삼성전기, 우리금융지주): 0.9405357906718069
# (삼성전기, 두산에너빌리티): 0.8329649806805947
# (삼성전기, 고려아연): 0.7536237383793192
# (삼성전기, HD현대일렉트릭): 0.9202226466158092
# (삼성전기, HD한국조선해양): 0.9112276499663106
# (삼성전기, 삼성중공업): 0.9388824630574698
# (삼성전기, 포스코인터내셔널): 0.8150461358499713
# (삼성전기, 대한항공): 0.8864783749142091
# (삼성전기, 한국타이어앤테크놀로지): 0.913023868880458
# (삼성전기, 현대글로비스): 0.9302306308551349
# (삼성전기, LG생활건강): 0.5294375643000672
# (삼성전기, 한국항공우주): 0.8285735669132301
# (삼성전기, LG디스플레이): 0.9279334559074213
# (삼성전기, LG이노텍): 0.7286794036363222
# (삼성전기, SKC): 0.8616282776116608
# (삼성전기, LG유플러스): 0.8062212764453939
# (삼성전기, 한화솔루션): 0.9401401921773568
# (삼성전기, 한미약품): 0.7994818059981855
# (삼성전기, NH투자증권): 0.88474055309624
# (SK텔레콤, 기업은행): 0.7304632923443329
# (SK텔레콤, SK이노베이션): 0.7794082567660763
# (SK텔레콤, 우리금융지주): 0.8300883683361441
# (SK텔레콤, 두산에너빌리티): 0.7583538301581955
# (SK텔레콤, 고려아연): 0.792674502222714
# (SK텔레콤, HD현대일렉트릭): 0.9452714105434387
# (SK텔레콤, HD한국조선해양): 0.6731571197751127
# (SK텔레콤, S-Oil): 0.6700431482168859
# (SK텔레콤, 삼성중공업): 0.7798588434723851
# (SK텔레콤, 포스코인터내셔널): 0.8673405131290863
# (SK텔레콤, 대한항공): 0.8154940970483141
# (SK텔레콤, 한국타이어앤테크놀로지): 0.8610997916398515
# (SK텔레콤, 현대글로비스): 0.8567420984651474
# (SK텔레콤, LG생활건강): 0.7926591431368798
# (SK텔레콤, 유한양행): 0.633578374908531
# (SK텔레콤, 한국항공우주): 0.90432797622357
# (SK텔레콤, LG디스플레이): 0.7076998481903071
# (SK텔레콤, LG이노텍): 0.7525763576978491
# (SK텔레콤, 현대로템): 0.7106316815406448
# (SK텔레콤, SKC): 0.9365306238015884
# (SK텔레콤, 롯데케미칼): 0.6284983492623383
# (SK텔레콤, LG유플러스): 0.9517127526732536
# (SK텔레콤, 한화솔루션): 0.8234373765982997
# (SK텔레콤, 한미약품): 0.7986060740261496
# (SK텔레콤, NH투자증권): 0.8144151723657265
# (기업은행, SK이노베이션): 0.9041247614929226
# (기업은행, 우리금융지주): 0.9639834586810261
# (기업은행, 두산에너빌리티): 0.9062618051072177
# (기업은행, 고려아연): 0.8096405726822298
# (기업은행, HD현대일렉트릭): 0.8517700715712087
# (기업은행, HD한국조선해양): 0.94579862821099
# (기업은행, S-Oil): 0.523645161944092
# (기업은행, 삼성중공업): 0.9451252818378384
# (기업은행, 포스코인터내셔널): 0.8576978148721435
# (기업은행, 대한항공): 0.8911206367641511
# (기업은행, 한국타이어앤테크놀로지): 0.9244980093923066
# (기업은행, 현대글로비스): 0.937956759090738
# (기업은행, 유한양행): 0.5316883966725222
# (기업은행, 한국항공우주): 0.8147514674259678
# (기업은행, LG디스플레이): 0.9630660789706653
# (기업은행, LG이노텍): 0.7858122626986791
# (기업은행, SKC): 0.7824929618569435
# (기업은행, LG유플러스): 0.7638118555597192
# (기업은행, 한화솔루션): 0.9662561509188132
# (기업은행, 한미약품): 0.8640548847987263
# (기업은행, NH투자증권): 0.9326543356923119
# (SK이노베이션, 우리금융지주): 0.8850773317929616
# (SK이노베이션, 두산에너빌리티): 0.9186448328767869
# (SK이노베이션, 고려아연): 0.9550776841715284
# (SK이노베이션, HD현대일렉트릭): 0.8709461399569184
# (SK이노베이션, HD한국조선해양): 0.7684161829631633
# (SK이노베이션, S-Oil): 0.7974884324546204
# (SK이노베이션, 삼성중공업): 0.8161063727010318
# (SK이노베이션, 포스코인터내셔널): 0.939604634091066
# (SK이노베이션, 대한항공): 0.8463104567106512
# (SK이노베이션, 한국타이어앤테크놀로지): 0.8831770358445233
# (SK이노베이션, 현대글로비스): 0.8936849702612221
# (SK이노베이션, LG생활건강): 0.6357574918793736
# (SK이노베이션, 유한양행): 0.7651996095896585
# (SK이노베이션, 한국항공우주): 0.9177151218409223
# (SK이노베이션, LG디스플레이): 0.8146543512596107
# (SK이노베이션, LG이노텍): 0.9158216821825267
# (SK이노베이션, 현대로템): 0.606697665927984
# (SK이노베이션, SKC): 0.873351244059709
# (SK이노베이션, 롯데케미칼): 0.702700118700156
# (SK이노베이션, LG유플러스): 0.8728385583945004
# (SK이노베이션, 한화솔루션): 0.9117431047749288
# (SK이노베이션, 한미약품): 0.9073122199753797
# (SK이노베이션, 한진칼): 0.6316032745088023
# (SK이노베이션, NH투자증권): 0.9125750838278509
# (우리금융지주, 두산에너빌리티): 0.8894166418997588
# (우리금융지주, 고려아연): 0.8075021350914428
# (우리금융지주, HD현대일렉트릭): 0.9250335623256177
# (우리금융지주, HD한국조선해양): 0.8998040187581018
# (우리금융지주, S-Oil): 0.5787774772971165
# (우리금융지주, 삼성중공업): 0.9222930940355943
# (우리금융지주, 포스코인터내셔널): 0.8836866861055571
# (우리금융지주, 대한항공): 0.872453920143788
# (우리금융지주, 한국타이어앤테크놀로지): 0.9252033924962666
# (우리금융지주, 현대글로비스): 0.9407804888377004
# (우리금융지주, LG생활건강): 0.5460672259472856
# (우리금융지주, 유한양행): 0.5441169989888175
# (우리금융지주, 한국항공우주): 0.8722132188871953
# (우리금융지주, LG디스플레이): 0.9191881211408682
# (우리금융지주, LG이노텍): 0.8039902074717127
# (우리금융지주, SKC): 0.8635298998571445
# (우리금융지주, 롯데케미칼): 0.5381087967361481
# (우리금융지주, LG유플러스): 0.8344932092669091
# (우리금융지주, 한화솔루션): 0.9621308133950178
# (우리금융지주, 한미약품): 0.8291991609898294
# (우리금융지주, NH투자증권): 0.9189535235312073
# (두산에너빌리티, 고려아연): 0.8419188319531088
# (두산에너빌리티, HD현대일렉트릭): 0.8810236972204294
# (두산에너빌리티, HD한국조선해양): 0.826448657402548
# (두산에너빌리티, S-Oil): 0.6668229009264447
# (두산에너빌리티, 삼성중공업): 0.8569995449505413
# (두산에너빌리티, 포스코인터내셔널): 0.8992660366642027
# (두산에너빌리티, 대한항공): 0.8237740771426991
# (두산에너빌리티, 한국타이어앤테크놀로지): 0.8849873655263369
# (두산에너빌리티, 현대글로비스): 0.8792539233717372
# (두산에너빌리티, LG생활건강): 0.58266683308271
# (두산에너빌리티, 유한양행): 0.7158860343752378
# (두산에너빌리티, 한국항공우주): 0.863078810340144
# (두산에너빌리티, LG디스플레이): 0.8501943618706972
# (두산에너빌리티, LG이노텍): 0.843650387538525
# (두산에너빌리티, 현대로템): 0.5393534406584528
# (두산에너빌리티, SKC): 0.8262638152122241
# (두산에너빌리티, 롯데케미칼): 0.5571029748546897
# (두산에너빌리티, LG유플러스): 0.8102655069366984
# (두산에너빌리티, 한화솔루션): 0.922093803873058
# (두산에너빌리티, 한미약품): 0.8885232776574998
# (두산에너빌리티, 한진칼): 0.5549824127651359
# (두산에너빌리티, NH투자증권): 0.8887683123605546
# (고려아연, HD현대일렉트릭): 0.8256525821873525
# (고려아연, HD한국조선해양): 0.6523187093213703
# (고려아연, S-Oil): 0.8105623095348555
# (고려아연, 삼성중공업): 0.7285915126769323
# (고려아연, 포스코인터내셔널): 0.9132006548487304
# (고려아연, 대한항공): 0.8167081168051958
# (고려아연, 한국타이어앤테크놀로지): 0.8350091668580031
# (고려아연, 현대글로비스): 0.8468642559601527
# (고려아연, LG생활건강): 0.6558876484355027
# (고려아연, 유한양행): 0.7856671932057891
# (고려아연, 한국항공우주): 0.8932243784924663
# (고려아연, LG디스플레이): 0.7184362094068343
# (고려아연, LG이노텍): 0.9011757609804779
# (고려아연, 현대로템): 0.6541866551322401
# (고려아연, SKC): 0.8874183126479873
# (고려아연, 롯데케미칼): 0.7302442072339734
# (고려아연, LG유플러스): 0.8895902332348045
# (고려아연, 한화솔루션): 0.8366514191366139
# (고려아연, 한미약품): 0.8851765938314569
# (고려아연, 한진칼): 0.6764810545484576
# (고려아연, NH투자증권): 0.8548587859821057
# (HD현대일렉트릭, HD한국조선해양): 0.7860516826226367
# (HD현대일렉트릭, S-Oil): 0.6877472483281584
# (HD현대일렉트릭, 삼성중공업): 0.8553706342816166
# (HD현대일렉트릭, 포스코인터내셔널): 0.905854141108225
# (HD현대일렉트릭, 대한항공): 0.8536869486158499
# (HD현대일렉트릭, 한국타이어앤테크놀로지): 0.9018704455357851
# (HD현대일렉트릭, 현대글로비스): 0.8983479365324148
# (HD현대일렉트릭, LG생활건강): 0.752028494910804
# (HD현대일렉트릭, 유한양행): 0.6551261666591611
# (HD현대일렉트릭, 한국항공우주): 0.9389239691814459
# (HD현대일렉트릭, LG디스플레이): 0.8163827582115101
# (HD현대일렉트릭, LG이노텍): 0.8333352843790345
# (HD현대일렉트릭, 현대로템): 0.6994558496309072
# (HD현대일렉트릭, SKC): 0.9513831837338567
# (HD현대일렉트릭, 롯데케미칼): 0.6577207810756295
# (HD현대일렉트릭, LG유플러스): 0.929185729247125
# (HD현대일렉트릭, 한화솔루션): 0.9194465514945747
# (HD현대일렉트릭, 한미약품): 0.8426873954107204
# (HD현대일렉트릭, 한진칼): 0.5467187217546424
# (HD현대일렉트릭, NH투자증권): 0.886334403559716
# (HD한국조선해양, 삼성중공업): 0.9756132319358617
# (HD한국조선해양, 포스코인터내셔널): 0.7531957727730247
# (HD한국조선해양, 대한항공): 0.868849354600548
# (HD한국조선해양, 한국타이어앤테크놀로지): 0.8995228018034797
# (HD한국조선해양, 현대글로비스): 0.9055728204093464
# (HD한국조선해양, 한국항공우주): 0.6825278426134395
# (HD한국조선해양, LG디스플레이): 0.9815183628278404
# (HD한국조선해양, LG이노텍): 0.6203486042403398
# (HD한국조선해양, SKC): 0.6644268031822639
# (HD한국조선해양, LG유플러스): 0.6532067243247613
# (HD한국조선해양, 한화솔루션): 0.9205566407975445
# (HD한국조선해양, 한미약품): 0.7835787824273935
# (HD한국조선해양, NH투자증권): 0.8624084617812673
# (S-Oil, 포스코인터내셔널): 0.8365680153394571
# (S-Oil, 대한항공): 0.515597953116218
# (S-Oil, 한국타이어앤테크놀로지): 0.6109444064701769
# (S-Oil, 현대글로비스): 0.6082214510222256
# (S-Oil, LG생활건강): 0.8128992074396061
# (S-Oil, 유한양행): 0.8352033028629349
# (S-Oil, 한국항공우주): 0.7842756919831251
# (S-Oil, LG이노텍): 0.8198573412318827
# (S-Oil, 현대로템): 0.7648508779976032
# (S-Oil, SKC): 0.7286261508610417
# (S-Oil, 롯데케미칼): 0.7791959783388979
# (S-Oil, LG유플러스): 0.814877216296658
# (S-Oil, 한화솔루션): 0.5716914342178815
# (S-Oil, 한미약품): 0.6793369286139666
# (S-Oil, 한진칼): 0.7972754708305156
# (S-Oil, NH투자증권): 0.6097792982087167
# (삼성중공업, 포스코인터내셔널): 0.8197652420104466
# (삼성중공업, 대한항공): 0.919945230040497
# (삼성중공업, 한국타이어앤테크놀로지): 0.9567993446947906
# (삼성중공업, 현대글로비스): 0.9567527113170584
# (삼성중공업, 한국항공우주): 0.7548674230196164
# (삼성중공업, LG디스플레이): 0.9702906563893645
# (삼성중공업, LG이노텍): 0.6491270018587312
# (삼성중공업, SKC): 0.7545121030271246
# (삼성중공업, LG유플러스): 0.7544842971124855
# (삼성중공업, 한화솔루션): 0.955385283305353
# (삼성중공업, 한미약품): 0.829273929460861
# (삼성중공업, NH투자증권): 0.9021848264070229
# (포스코인터내셔널, 대한항공): 0.8403597436353424
# (포스코인터내셔널, 한국타이어앤테크놀로지): 0.9159224514177109
# (포스코인터내셔널, 현대글로비스): 0.9166280751627719
# (포스코인터내셔널, LG생활건강): 0.7279858104139999
# (포스코인터내셔널, 유한양행): 0.8034110842014461
# (포스코인터내셔널, 한국항공우주): 0.9293616621496672
# (포스코인터내셔널, LG디스플레이): 0.7787872365729612
# (포스코인터내셔널, LG이노텍): 0.8985796108236153
# (포스코인터내셔널, 현대로템): 0.6379944555705385
# (포스코인터내셔널, SKC): 0.8816670208099807
# (포스코인터내셔널, 롯데케미칼): 0.6736366322572188
# (포스코인터내셔널, LG유플러스): 0.9458645577438207
# (포스코인터내셔널, 한화솔루션): 0.8832407738250971
# (포스코인터내셔널, 한미약품): 0.9122288472737855
# (포스코인터내셔널, 한진칼): 0.6851682484217828
# (포스코인터내셔널, NH투자증권): 0.8995222841078908
# (대한항공, 한국타이어앤테크놀로지): 0.9384544320550208
# (대한항공, 현대글로비스): 0.9259208935934437
# (대한항공, 유한양행): 0.5885314009683819
# (대한항공, 한국항공우주): 0.8175126227232589
# (대한항공, LG디스플레이): 0.9084344155375729
# (대한항공, LG이노텍): 0.6794093766650913
# (대한항공, SKC): 0.8099773426470802
# (대한항공, LG유플러스): 0.8203701170014229
# (대한항공, 한화솔루션): 0.9441082501188448
# (대한항공, 한미약품): 0.8876222654601217
# (대한항공, NH투자증권): 0.9477377725884207
# (한국타이어앤테크놀로지, 현대글로비스): 0.9848793037471569
# (한국타이어앤테크놀로지, LG생활건강): 0.5197912410789893
# (한국타이어앤테크놀로지, 유한양행): 0.6137478537528956
# (한국타이어앤테크놀로지, 한국항공우주): 0.8444172403513861
# (한국타이어앤테크놀로지, LG디스플레이): 0.9111192510397256
# (한국타이어앤테크놀로지, LG이노텍): 0.7399811492572415
# (한국타이어앤테크놀로지, SKC): 0.8414227722539767
# (한국타이어앤테크놀로지, LG유플러스): 0.8690342481965027
# (한국타이어앤테크놀로지, 한화솔루션): 0.9507656391522484
# (한국타이어앤테크놀로지, 한미약품): 0.8883784330270894
# (한국타이어앤테크놀로지, NH투자증권): 0.9281455917652649
# (현대글로비스, LG생활건강): 0.5246893936627587
# (현대글로비스, 유한양행): 0.5850720132650178
# (현대글로비스, 한국항공우주): 0.8463147139807692
# (현대글로비스, LG디스플레이): 0.9172833513251005
# (현대글로비스, LG이노텍): 0.7562605770609028
# (현대글로비스, SKC): 0.854593254934084
# (현대글로비스, LG유플러스): 0.8627596297317588
# (현대글로비스, 한화솔루션): 0.9508111206216638
# (현대글로비스, 한미약품): 0.8824740268499193
# (현대글로비스, NH투자증권): 0.9238031016398685
# (LG생활건강, 유한양행): 0.699687812317741
# (LG생활건강, 한국항공우주): 0.8079075099941943
# (LG생활건강, LG이노텍): 0.7558505001894152
# (LG생활건강, 현대로템): 0.9036878307582571
# (LG생활건강, SKC): 0.7829854389354614
# (LG생활건강, 롯데케미칼): 0.7852261296704186
# (LG생활건강, LG유플러스): 0.81466270979205
# (LG생활건강, 한화솔루션): 0.5058741281886201
# (LG생활건강, 한미약품): 0.5768223175551723
# (LG생활건강, 한진칼): 0.6625837085040622
# (LG생활건강, NH투자증권): 0.5217299308821152
# (유한양행, 한국항공우주): 0.7627816542550343
# (유한양행, LG이노텍): 0.7883585816223675
# (유한양행, 현대로템): 0.6919049187226859
# (유한양행, SKC): 0.703690396355373
# (유한양행, 롯데케미칼): 0.7869100404680927
# (유한양행, LG유플러스): 0.7563183216405193
# (유한양행, 한화솔루션): 0.5893015324673561
# (유한양행, 한미약품): 0.789521385810795
# (유한양행, 한진칼): 0.8319859897376232
# (유한양행, NH투자증권): 0.6553092682067501
# (한국항공우주, LG디스플레이): 0.7336998519656651
# (한국항공우주, LG이노텍): 0.9045657566635962
# (한국항공우주, 현대로템): 0.7827158250888746
# (한국항공우주, SKC): 0.9479373647589324
# (한국항공우주, 롯데케미칼): 0.7945658566322656
# (한국항공우주, LG유플러스): 0.938224195255192
# (한국항공우주, 한화솔루션): 0.8775586585623232
# (한국항공우주, 한미약품): 0.8669268349042001
# (한국항공우주, 한진칼): 0.6406646653864975
# (한국항공우주, NH투자증권): 0.8846255929610716
# (LG디스플레이, LG이노텍): 0.6734842136635484
# (LG디스플레이, SKC): 0.7234145882150204
# (LG디스플레이, LG유플러스): 0.6914893709506548
# (LG디스플레이, 한화솔루션): 0.9512944583925644
# (LG디스플레이, 한미약품): 0.8322738357229935
# (LG디스플레이, NH투자증권): 0.904906259941235
# (LG이노텍, 현대로템): 0.7485587880228031
# (LG이노텍, SKC): 0.8550677015255299
# (LG이노텍, 롯데케미칼): 0.8111210745728218
# (LG이노텍, LG유플러스): 0.8552171206538999
# (LG이노텍, 한화솔루션): 0.778477985612035
# (LG이노텍, 한미약품): 0.8452869735670506
# (LG이노텍, 한진칼): 0.7494673855604671
# (LG이노텍, NH투자증권): 0.7924117544331918
# (현대로템, SKC): 0.7866857259199022
# (현대로템, 롯데케미칼): 0.8929075025088768
# (현대로템, LG유플러스): 0.7469256176300662
# (현대로템, 한미약품): 0.5217066246139258
# (현대로템, 한진칼): 0.6986975005663102
# (SKC, 롯데케미칼): 0.7462831334231389
# (SKC, LG유플러스): 0.9256925544141417
# (SKC, 한화솔루션): 0.8614524370243429
# (SKC, 한미약품): 0.8179405180177195
# (SKC, 한진칼): 0.6143326879491198
# (SKC, NH투자증권): 0.8315612333440923
# (롯데케미칼, LG유플러스): 0.7392743559007012
# (롯데케미칼, 한화솔루션): 0.5161205673273079
# (롯데케미칼, 한미약품): 0.6065389152695925
# (롯데케미칼, 한진칼): 0.7886753651536078
# (롯데케미칼, NH투자증권): 0.5766120050400441
# (LG유플러스, 한화솔루션): 0.8307369746106014
# (LG유플러스, 한미약품): 0.8554221170037246
# (LG유플러스, 한진칼): 0.6391417193780512
# (LG유플러스, NH투자증권): 0.8570806919995798
# (한화솔루션, 한미약품): 0.8907289774933574
# (한화솔루션, NH투자증권): 0.9641160377046318
# (한미약품, 한진칼): 0.5642282222689174
# (한미약품, NH투자증권): 0.9270020625755241

# %%
font_path = "C:/Windows/Fonts/malgun.ttf"  # 폰트 파일 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# %%
sectors = pd.unique(df["업종명"])
color_map = plt.get_cmap('tab20', len(sectors))
sector_color = {sector: color_map(i) for i, sector in enumerate(sectors)}

node_colors = [sector_color[G.nodes[node]['sector']] for node in G.nodes]

legend_patches = [mpatches.Patch(color=sector_color[sector], label=sector) for sector in sectors]

plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G, k=2)  # k 값을 조정하여 노드 간 거리 조정
weights = nx.get_edge_attributes(G, 'weight').values()

# 라벨 위치 조정
labels = {node: node for node in G.nodes}
nx.draw(G, pos, with_labels=False, node_color=node_colors, edge_color='lightgray', width=list(weights))
for p in pos:  # 라벨을 노드 옆에 배치
    pos[p][0] += 0.05
nx.draw_networkx_labels(G, pos, labels, font_family=font_prop.get_name(), font_size=8)

plt.title('Graph with Correlation as Edge Weights', fontproperties=font_prop)
plt.legend(handles=legend_patches, loc='best', title='업종명', prop=font_prop)
plt.show()

# %% [markdown]
# # MST

# %%
mst = nx.minimum_spanning_tree(G)

# %%
plt.figure(figsize=(15, 10))  
pos = nx.planar_layout(mst)  # 엣지 교차를 줄이기 위해 planar_layout 사용

nx.draw(mst, pos, with_labels=False, node_color=node_colors, edge_color='black', width=2, node_size=300)
nx.draw_networkx_labels(mst, pos, labels={node: node for node in mst.nodes()}, font_family=font_prop.get_name(), font_size=8)
plt.title("Minimun Spanning Tree", fontproperties=font_prop)
plt.legend(handles=legend_patches, loc='best', title='업종명', prop=font_prop)
plt.show()

# %%
def analyze_graph(G):
    # 평균 거리 (전체 노드 간 최단 경로의 평균)
    avg_distance = nx.average_shortest_path_length(G)
    
    # 최대 거리 (지름)
    diameter = nx.diameter(G)
    
    # Branch count
    branch_count = sum(1 for node in G.nodes if G.degree(node) > 2)
    
    # 분석 결과 반환
    return {
        # "Average Distance": avg_distance,
        # "Diameter": diameter,
        "Branch Count": branch_count
    }

# %%
mst_analysis = analyze_graph(mst)

for key, value in mst_analysis.items():
    print(f"{key}: {value}")
# Out:
# Branch Count: 7

# %% [markdown]
# # Centrality Analysis

# %%
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G)

# %%
centrality_df = pd.DataFrame({
    '종목코드': list(G.nodes),
    '업종명': [G.nodes[node]['sector'] for node in G.nodes],
    'Degree Centrality': [degree_centrality[node] for node in G.nodes],
    'Betweenness Centrality': [betweenness_centrality[node] for node in G.nodes],
    'Closeness Centrality': [closeness_centrality[node] for node in G.nodes],
    'Eigenvector Centrality': [eigenvector_centrality[node] for node in G.nodes]
})

# %%
for centrality in ['Degree Centrality', 'Betweenness Centrality', 'Closeness Centrality', 'Eigenvector Centrality']:
    print(f"Top 5 {centrality}")
    display(centrality_df[['종목코드', '업종명', centrality]].nlargest(5, centrality))
    print("\n")
# Out:
# Top 5 Degree Centrality
#          종목코드   업종명  Degree Centrality
# 4        LG화학    화학                1.0
# 5      포스코퓨처엠  전기전자                1.0
# 8         카카오  서비스업                1.0
# 9        삼성생명    보험                1.0
# 13  한화에어로스페이스  운수장비                1.0
# Top 5 Betweenness Centrality
#          종목코드   업종명  Betweenness Centrality
# 4        LG화학    화학                0.003828
# 5      포스코퓨처엠  전기전자                0.003828
# 8         카카오  서비스업                0.003828
# 9        삼성생명    보험                0.003828
# 13  한화에어로스페이스  운수장비                0.003828
# Top 5 Closeness Centrality
#          종목코드   업종명  Closeness Centrality
# 4        LG화학    화학                   1.0
# 5      포스코퓨처엠  전기전자                   1.0
# 8         카카오  서비스업                   1.0
# 9        삼성생명    보험                   1.0
# 13  한화에어로스페이스  운수장비                   1.0
# Top 5 Eigenvector Centrality
#          종목코드   업종명  Eigenvector Centrality
# 4        LG화학    화학                0.161526
# 5      포스코퓨처엠  전기전자                0.161526
# 8         카카오  서비스업                0.161526
# 9        삼성생명    보험                0.161526
# 13  한화에어로스페이스  운수장비                0.161526

# %% [markdown]
# # Influence Maximization

# %%
import random

# 독립적 연접 모델을 사용한 영향 평가 함수
def independent_cascade(G, seed_nodes, steps=1000):
    influenced_nodes = set(seed_nodes)
    new_active = set(seed_nodes)
    for _ in range(steps):
        if not new_active:
            break
        next_active = set()
        for node in new_active:
            for neighbor in G.neighbors(node):
                if neighbor not in influenced_nodes and random.random() < G[node][neighbor]['weight']:
                    next_active.add(neighbor)
        influenced_nodes.update(next_active)
        new_active = next_active
    return len(influenced_nodes)

# %%
# Greedy Algorithm을 사용한 시드 노드 선택
def greedy_algorithm(G, k, steps=1000):
    seed_nodes = []
    for _ in tqdm(range(k)):
        best_node = None
        max_influence = -1
        for node in tqdm(G.nodes):
            if node not in seed_nodes:
                influence = independent_cascade(G, seed_nodes + [node], steps)
                if influence > max_influence:
                    best_node = node
                    max_influence = influence
        seed_nodes.append(best_node)
    return seed_nodes

# %%
# 시드 노드 수 설정
k = 1

# Greedy Algorithm을 사용하여 시드 노드 선택
seed_nodes = greedy_algorithm(G, k)
print(f"Selected seed nodes: {seed_nodes}")
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 4767.86it/s]
# 100%|██████████| 1/1 [00:00<00:00, 55.45it/s]
# Selected seed nodes: ['삼성전자']

# %%
font_path = "C:/Windows/Fonts/malgun.ttf"  # 폰트 파일 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# 시각화 (선택된 시드 노드를 강조하여 표시)
pos = nx.spring_layout(G, k=2)
node_colors = ['red' if node in seed_nodes else 'skyblue' for node in G.nodes]

plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, node_color=node_colors, edge_color='lightgray', node_size=300, font_size=8, font_family=font_prop.get_name())  # 노드 크기 조정
plt.title("Influence Maximization", fontproperties=font_prop)
plt.show()

# %% [markdown]
# # Community Detection

# %%
import community as community_louvain

partition = community_louvain.best_partition(G)

# 커뮤니티별로 노드 색상 지정
colors = [partition[node] for node in G.nodes()]

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 폰트 파일 경로
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# 그래프 시각화
pos = nx.spring_layout(G, k=1)
plt.figure(figsize=(12, 8))

nx.draw(G, pos, node_color=colors, with_labels=True, cmap=plt.cm.rainbow, node_size=100, edge_color='lightgray', font_size=8, font_family=font_prop.get_name())
plt.title("Community Detection", fontproperties=font_prop)

plt.show()

# %%
community_df = pd.DataFrame.from_dict(partition, orient='index', columns=['커뮤니티'])
community_df['종목명'] = community_df.index
community_df.reset_index(drop=True, inplace=True)

# 업종명 추가
community_df = community_df.merge(df[['종목명', '업종명']], on='종목명')

# 커뮤니티와 업종명 카운트 피벗 테이블 생성
pivot_table = community_df.pivot_table(index='커뮤니티', columns='업종명', aggfunc='size', fill_value=0)

# 커뮤니티 이름을 "community 1", "community 2" 형식으로 변경
pivot_table.index = [f"community {i+1}" for i in range(len(pivot_table))]

pivot_table
# Out:
# 업종명          기계  기타금융  보험  서비스업  운수장비  운수창고업  유통업  은행  의약품  전기전자  증권  철강금속  \
# community 1   1     5   1     1     3      3    0   1    1     5   1     0
# community 2   0     1   0     3     4      1    1   0    2     3   0     1
#
# 업종명          통신업  화학
# community 1    0   3
# community 2    2   6
